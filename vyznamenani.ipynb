# %% [markdown]
# # Státní vyznamenání: explorace dat
#
# ### Elevator pitch (stále nekompletní)
#
# Víme, jak vyznamenávali jednotliví čeští prezidenti! Možná i líp než oni sami.
#
# Trošičku nám ten rituál za Zemana upadá:
#
# - Přibývá znovuvyznamenaných.
# - Všem 1. třídy a 1. stupně.
# - Ubývá významných (ŘBL).
# - Pro in memoriam saháme dále do minulosti (ŘBL).
#
# ## Osnova
#
# ### teaser-anketa
#
# - Zeman naposled
# - na koho se zapomnělo?
# - zajímavej způsob, jak vybrat významné lidi: Notable People
# - metodologie
# - žebříček českých (tabulka)
# - žebříček nevyznamenaných - hlasování
# - vybírat nemůžete, můžete jim doplnit profily na wiki
#
# ### úvod
#
# - třetí prezident uzavírá svůj druhý mandát, čas bilancovat!
# - máme tyto 2 řády a tyto 2 medaile, za co
#
# ### stať
#
# - kdo jich rozdal kolik a jakých stupňů, kdo vyznamenával ženy, kdo mrtvé
#     - Havel toho rozdával nejvíc, a to i na konci mandátu, kdy už uplynulo 13 let od revoluce a 10 od vyhlášení ČR (což asi byly důvody proto to házet z vrtulníku).
#     - Klaus šetřil prvními stupni a třídami, Zeman dává skoro jenom je.
#     - Klaus taky málo vyznamenával nebožtíky.
#     - Havel nevyznamenal moc žen, Klaus to trochu zlepšil, Zeman se držel, ale v druhém termínu to zas padá.
# - kdo z vyznamenaných byl "povýšen"
#     - Jenom Zeman znovuvyznamenává nositele státních vyznamenání ČR.
#
# ### touch of divno
#
# - vědci v Nature publikovali článek o tom, jak spočítat něčí významnost + rovnou publikovali dataset s 2 000 000 nejvýznamějších lidí historie (k roku 2019)
# - takto vypadá prolnutí seznamu vyznamenaných Řádem Bílého Lva a významných lidí
#     - velkej večírek byl v roce 1999, Havel vyznamenal globální elitu, pak úpadek, možná 2022 Zelenský
#     - 12 nejvýznamějších osobností ocenil Bílým lvem (nejvyšší vyznamenání) Havel, tu 13. Klaus, ale byl jí Havel.
#
# ### závěr
#
# - na které významné české (nebo i světové?) osobnosti by se mohl zaměřit příští prezident?
#
#
# ### Zbývá
#
# Sběr:
# - rozdělit 1 jméno do 2
# - Jindřich Macháček: narození a úmrtí. v knihovně: https://dnnt.mzk.cz/periodical/uuid:b56c15a0-acbf-11e7-91d5-005056825209?fulltext=%22Jind%C5%99ich%20Mach%C3%A1%C4%8Dek%22%20gener%C3%A1lmajor%20 nebo https://dnnt.mzk.cz/view/uuid:2891f1a0-a29b-11e2-9a9f-005056827e51?page=uuid:e002b1be-4335-45db-8444-321a3e156d5e&fulltext=%22mach%C3%A1%C4%8Dek%20jind%C5%99ich%22
# - zaměřit se na první republiku
# - fakin kontrola
# - našinci x cizinci
#
# Analýza:
# - multiples/skokani
#
# Co nejjednodušší analýza archiválií:
# - kolik vyznamenání ročně se dávalo za ČSR a ČSSR
#
# Porovnání se zahraničím?
# - Slovensko?
#
#
# ### Výpisky
#
# - Řád Bílého lva je nejvyšší státní vyznamenání České republiky. Původně byl udělován osobám, které se zvlášť vynikajícím způsobem zasloužily o Československo, a to od roku 1922. V letech 1922–1990 se tento řád oficiálně nazýval „Československý řád Bílého lva“.
#     - _Řád Bílého lva propůjčuje nebo uděluje prezident republiky a) občanům České republiky za zvláště vynikající zásluhy o stát, zejména v oblasti politiky, správy státu, rozvoje hospodářství, vědy, techniky, kultury, umění, školství, za mimořádné zásluhy o obranu a bezpečnost státu, za vynikající velitelskou a bojovou činnost, za vědeckou a odbornou práci vojenského a branného charakteru a za významné proslavení vlasti v zahraničí, b) těm, kteří nejsou občany České republiky, za zvláště vynikající zásluhy ve prospěch České republiky._
#     - S řádovým řetězem se vyznamenání uděluje pouze hlavám států.
#     - Českým státním občanům se řád neuděluje, ale propůjčuje.
#
# - Řád Tomáše Garrigua Masaryka je vyšším státním vyznamenáním České republiky a bývalého Československa. Prezident republiky je uděluje nebo propůjčuje osobám, které se vynikajícím způsobem zasloužily o rozvoj demokracie, humanity a lidských práv. Řád vznikl v roce 1990 jako vyznamenání určené pouze pro československé občany; po rozpadu federace byl obnoven roku 1994.
#     - _Řád Tomáše Garrigua Masaryka (dále jen "Řád T.G.M.") propůjčuje nebo uděluje prezident republiky osobám, které se vynikajícím způsobem zasloužily o rozvoj demokracie, humanity a lidská práva._
#
# - Medaile Za hrdinství je nižší státní vyznamenání České republiky.
#     - _Medaili Za hrdinství uděluje prezident republiky osobám za hrdinství v boji a těm, kteří se s nasazením vlastního života zasloužili o záchranu lidského života nebo značných materiálních hodnot._
#
# - Medaile Za zásluhy je nižší státní vyznamenání České republiky.
#     - Vznikla v roce 1990. Medaili Za zásluhy uděluje prezident republiky osobám, které se zasloužily o stát nebo územní samosprávný celek v oblasti hospodářské, vědy, techniky, kultury, umění, sportu, výchovy a školství, obrany, bezpečnosti státu a občanů. Dělí se do tří stupňů, kterým odpovídá materiál a počet fialových pruhů na stužce.[1] I. stupeň medaile je nejvyšší, je ražen ze stříbra a pozlacen, II. stupeň je ražen ze stříbra a III. stupeň je ražen z bronzu. Výtvarným autorem medaile je Jiří Harcuba.
#        - _Medaili Za zásluhy uděluje prezident republiky osobám, které se zasloužily o stát nebo územní samosprávný celek v oblasti hospodářské, vědy, techniky, kultury, umění, sportu, výchovy a školství, obrany, bezpečnosti státu a občanů._
#
# - Medaile Za hrdinství je nižší státní vyznamenání České republiky. Je udělováno jako vyznamenání osob za hrdinství v boji a vyznamenání těch osob, které se s nasazením vlastního života zasloužily o záchranu lidského života nebo značných materiálních hodnot.
#
# - Prezident České a Slovenské federativní republiky, jenž byl zároveň i automatickým nositelem řádové insignie I. třídy Řádu Milana Rastislava Štefánika (dále jen Řád M. R. Štefánika) měl pravomoc - propůjčit řád navrhovaným osobnostem. Vrácení prezidentovy insignie (I. třídy řádu) nastalo jen v případě neprodloužení lhůty o propůjčení řádu i po dobu skončení prezidentské funkce prostřednictvím usnesení Federálního shromáždění. Vyznamenávání osob prezidentem ČSFR příslušným řádem se konalo vždy 8. 5. Tento den byl považován za řádový den se symbolikou ukončení druhé světové války v Evropě.132 Zákon nepovoloval propůjčení řádu v jiný den než v řádový den.
#
# ***
#
# Slavnostní ceremoniál se konal již tradičně 28. října 1992 ve Vladislavském sále na Pražském hradě. Řád Tomáše Garriguea Masaryka (dále jen T. G. Masaryka) byl propůjčen 64 osobnostem ve IV. stupni. Zákonní navrhovatelé115 se dohodli o tom, že v tomto roce vyznamenání T. G Masaryka propůjčí pouze nežijícím osobnostem in memoriam. 116 V takovém případě získávali pozůstalí vyznamenaného pouze listinu o propůjčení vyznamenání, nikoli řádovou insignii vyznamenání.117
#
# Další změnou oproti předchozímu předávání řádu (v roce 1991), prezident České a Slovenské federativní republiky (dále jen ČSFR) - Václav Havel rezignoval tehdy na svůj post, a tak předávání se ujal (dle zákonné pravomoci) předseda vlády ČSFR, Jan Stráský.118
#
# Televizní záznam předávání státního vyznamenání T. G. Masaryka nebyl nikdy odvysílán. Z celkového audiovizuálního materiálu se použily jen krátké sestřihy do denního Zpravodajství a Deníku ČTV. O úvod a komentář záznamu se postaral Ladislav Špaček, tehdy jako šéfredaktor domácího zpravodajství ČT (v roce 1990).121
#
# ***
#
# Řád Bílého lva slaví sto let od vzniku. Původně však nebyl pro Čechy
# Zdroj: https://www.idnes.cz/zpravy/domaci/rad-bileho-lva-oceneni-sto-let-vznik-prezident-vladislavsky-sal.A221002_181046_domaci_albe
#
# ### Z datasetu Notable people:
#
# Kdo chybí z největších Čechů? (Medián lvů in memoriam: 35 let po smrti, rekord 88. Jako filtr nastaveno to druhé.)
# - Kurt_Gödel	mathematician	1978.0
# - Ivana_Trump	author	NaN
# - TGM 1937.0
# - Alphonse_Mucha	artist	1939.0
# - Ivan_Lendl	player	NaN
# - Tomáš_Rosický	football	NaN
# - Tomáš_Berdych	player	NaN
# - Miloš_Zeman	politician	NaN
# - Richard_von_Coudenhove-Kalergi	politician	1972.0
# - Edvard_Beneš	politician	1948.0
# - Tom_Stoppard	playwright	NaN
# - Karolína_Plíšková	player	NaN
# - Jozef_Tiso	politician	1947.0
# - Karolína_Kurková	model	NaN
# - Silvia_Saint	actor	NaN
# - Max_Brod	author	1968.0
# - Jan_Koller	football	NaN
# - Ivan_Reitman	film	NaN
#
# ### Otázky, na které neodpoví data – zeptat se lidí:
#
# - Proč se nevyznamenávalo 1993 a 1994?
# - Proč Zeman dává jen první třídy a stupně?
# - Podle čeho se rozhodovalo, komu po rozdělení federace dát metál znovu?
#
# ### Nepřesnosti na webu:
#
# Alfred Duff Cooper není in memoriam! Lech Aleksander Kaczyński taky ne! Patton dtto. Wtf. Vranitzky počeštěný.
#
# who the fuck is Aleš Weiter

# %% [markdown]
# ## Připrav se, hrajem

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cr_lev = pd.read_json("cr-rad-bileho-lva.json")
cr_masaryk = pd.read_json("cr-rad-t.-g.-masaryka.json")
cr_zasluhy = pd.read_json("cr-medaile-za-zasluhy.json")
cr_hrdinstvi = pd.read_json("cr-medaile-za-hrdinstvi.json")
csfr_lev = pd.read_json("csfr-rad-bileho-lva.json")
csfr_masaryk = pd.read_json("csfr-rad-t.-g.-masaryka.json")
csfr_stefanik = pd.read_json("csfr-rad-m.-r.-stefanika.json")
csfr_zasluhy = pd.read_json("csfr-medaile-za-zasluhy.json")
csfr_hrdinstvi = pd.read_json("csfr-medaile-za-hrdinstvi.json")

# %%
Havel = [1990, 1991, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002]
Klaus = [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]
Zeman = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
Strasky = [1992]

# %%
metaly = pd.concat([cr_lev, cr_masaryk, cr_zasluhy, cr_hrdinstvi, csfr_lev, csfr_masaryk, csfr_stefanik, csfr_hrdinstvi, csfr_zasluhy], axis=0, join='outer')

# %%
with open("zenskajmena.txt", 'r', encoding="utf-8") as zenskajmena:
    zenskajmena = zenskajmena.read().splitlines()
    zeny = []
    for line in zenskajmena:
        zeny.append(line + " ")

# %%
metaly.loc[metaly.jmeno.eq("Petra Kellner"),"jmeno"]="Petr Kellner"
metaly.loc[metaly.jmeno.eq("Hana"),"jmeno"]="Hana Hegerová"

metaly.loc[metaly.jmeno.eq("Hanuš"),"jmeno"]="Hanuš Holzer"
metaly.loc[metaly.jmeno.eq("Kare"),"jmeno"]="Karel Kryl"
metaly.loc[metaly.jmeno.eq("Karel"),"jmeno"]="Karel Hanzl"
metaly.loc[metaly.jmeno.eq("František"),"jmeno"]="František Kriegel"
metaly.loc[metaly.jmeno.eq("Detlef"),"jmeno"]="Detlef Lingemann"

metaly.loc[metaly.jmeno.eq("Alfred Duff Cooper"),"inmemoriam"]=True
metaly.loc[metaly.jmeno.eq("Lech Aleksander Kaczyński"),"inmemoriam"]=True
metaly.loc[metaly.jmeno.eq("George S. Patton"),"inmemoriam"]=True

# %%
metaly = metaly[metaly["jmeno"] != "Aleš Weiter"]

# %%
metaly.loc[(metaly["jmeno"] == "Karel Raška") & (metaly["rok"] == 2021),"jmeno"]="Karel Raška II."
metaly.loc[(metaly["jmeno"] == "Pavel Žák") & (metaly["rok"] == 2021),"jmeno"]="Pavel Žák II."
metaly.loc[(metaly["jmeno"] == "Jan Procházka") & (metaly["rok"] == 2017),"jmeno"]="Jan Procházka II."
metaly.loc[(metaly["jmeno"] == "Jaroslav Strnad") & (metaly["rok"] == 2018),"jmeno"]="Jaroslav Strnad II."

# %%
metaly["pohlavi"] = "muz"
metaly.loc[metaly.jmeno.str.contains('|'.join(zeny)),"pohlavi"]="zena"

# %%
metaly = metaly[metaly["rok"].notnull()]
metaly = metaly[metaly["jmeno"].notnull()]
metaly = metaly.sort_values(by="rok")

# %%
metaly.loc[metaly.rok.isin(Havel),"prezident"]="Havel"
metaly.loc[metaly.rok.isin(Klaus),"prezident"]="Klaus"
metaly.loc[metaly.rok.isin(Zeman),"prezident"]="Zeman"
metaly.loc[metaly.rok.isin(Strasky),"prezident"]="Stráský"

# %% [markdown]
# ## Kontrola

# %%
metaly.groupby("vyznamenani")["jmeno"].nunique()
# Out:
# vyznamenani
# medaile-za-hrdinstvi    138
# medaile-za-zasluhy      792
# rad-bileho-lva          123
# rad-m.-r.-stefanika      84
# rad-t.-g.-masaryka      353
# Name: jmeno, dtype: int64

# %%
metaly.sample(10)
# Out:
#      stat           vyznamenani                  jmeno     rok  rank  retez  \
# 389    cr    medaile-za-zasluhy         Ondrej Páleník  1998.0   3.0  False
# 427    cr    medaile-za-zasluhy     Jaroslav Procházka  1998.0   3.0  False
# 176    cr    rad-t.-g.-masaryka  Miloslav kardinál Vlk  2002.0   2.0  False
# 58     cr  medaile-za-hrdinstvi      Miroslav Liškutín  1996.0   NaN  False
# 1      cr    medaile-za-zasluhy      Jaroslava Adamová  2001.0   2.0  False
# 152  csfr    medaile-za-zasluhy      Zdeňka Táboříková  1992.0   3.0    NaN
# 101    cr  medaile-za-hrdinstvi        Boleslav Staněk  2009.0   NaN  False
# 619    cr    medaile-za-zasluhy       Rudolf Zahradník  1998.0   1.0  False
# 88     cr    medaile-za-zasluhy           Eva Erbenová  2020.0   1.0  False
# 91   csfr    rad-t.-g.-masaryka         Zdeněk Němeček  1992.0   4.0  False
#
#     skupina  inmemoriam pohlavi prezident
# 389     NaN       False     muz     Havel
# 427     NaN       False     muz     Havel
# 176     nan       False     muz     Havel
# 58      NaN       False     muz     Havel
# 1       NaN       False    zena     Havel
# 152     NaN       False    zena   Stráský
# 101     NaN        True     muz     Klaus
# 619     NaN       False     muz     Havel
# 88      NaN       False    zena     Zeman
# 91      NaN        True     muz   Stráský

# %% [markdown]
# ## Hledání trendů a rozdílů mezi prezidenty

# %%
lvi_pocet = pd.Series(metaly[metaly["vyznamenani"] == "rad-bileho-lva"].groupby("rok")["jmeno"].nunique())
masaryk_pocet = pd.Series(metaly[metaly["vyznamenani"] == "rad-t.-g.-masaryka"].groupby("rok")["jmeno"].nunique())
stefanik_pocet = pd.Series(metaly[metaly["vyznamenani"] == "rad-m.-r.-stefanika"].groupby("rok")["jmeno"].nunique())
zasluhy_pocet = pd.Series(metaly[metaly["vyznamenani"] == "medaile-za-zasluhy"].groupby("rok")["jmeno"].nunique())
hrdinstvi_pocet = pd.Series(metaly[metaly["vyznamenani"] == "medaile-za-hrdinstvi"].groupby("rok")["jmeno"].nunique())

# %%
roky = metaly["rok"].sort_values().drop_duplicates().to_list()

# %%
metaly_grouped_vyz = pd.DataFrame((metaly.groupby(["rok", "vyznamenani"])["jmeno"].nunique()).unstack())

# %%
metaly_grouped_vyz.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly_grouped_rank = pd.DataFrame((metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi")].groupby(["rok", "rank"])["jmeno"].nunique()).unstack())

# %%
metaly_grouped_rank.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %% [markdown]
# ⬆️GRAF1: Je podstatý tím, že:
#
# 1. Zachycuje porevoluční bonanzu,
#
# 2. zachycuje Havlovy medaile na konci funkčních období,
#
# 3. viditelně ukazuje propad 1. tříd a počtu vyznamenání obecně za Klause,
#
# 4. zachycuje Zemanovu inflaci 1. tříd.
#
# Nejsou tam vidět Medaile za hrdinství, které jediné nemají skupiny/třídy. Nevím, zda je tam cpát. Jsou do jistý míry ovlivněný tím, jestli ten rok zrovna někde v AFG nepadli vojáci.

# %%
pd.DataFrame((metaly.groupby(["rok", "vyznamenani"])["jmeno"].nunique()).unstack()).plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[(metaly["stat"] == "cr")].groupby("prezident")["jmeno"].nunique() / metaly[(metaly["stat"] == "cr")].groupby("prezident")["rok"].nunique()
# Out:
# prezident
# Havel    62.375000
# Klaus    26.600000
# Zeman    34.666667
# dtype: float64

# %%
34.777778 / 26.600000
# Out:
# 1.3074352631578945

# %%
metaly.groupby("rok")["jmeno"].nunique()
# Out:
# rok
# 1990.0      4
# 1991.0    153
# 1992.0    262
# 1995.0     54
# 1996.0     64
# 1997.0     69
# 1998.0    105
# 1999.0     35
# 2000.0     41
# 2001.0     46
# 2002.0     85
# 2003.0     57
# 2004.0     22
# 2005.0     23
# 2006.0     22
# 2007.0     24
# 2008.0     28
# 2009.0     24
# 2010.0     23
# 2011.0     21
# 2012.0     22
# 2013.0     30
# 2014.0     34
# 2015.0     35
# 2016.0     31
# 2017.0     43
# 2018.0     41
# 2019.0     42
# 2020.0     30
# 2021.0     27
# Name: jmeno, dtype: int64

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["stat"] == "cr") & (metaly["inmemoriam"] == True)].groupby("rok")["jmeno"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %% [markdown]
# In memoriam: Havel to rád studené, Klaus ne, Zeman sort of jo.

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["inmemoriam"] == True)].groupby("prezident")["jmeno"].nunique() / metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi")].groupby("prezident")["jmeno"].nunique()
# Out:
# prezident
# Havel      0.319716
# Klaus      0.079051
# Stráský    0.340996
# Zeman      0.189964
# Name: jmeno, dtype: float64

# %%
metaly[(metaly["vyznamenani"] == "medaile-za-zasluhy") & (metaly["stat"] == "cr") & (metaly["inmemoriam"] == False)].groupby("rok")["jmeno"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %% [markdown]
# A to je zajímavé: rok před koncem mandátu rozdat medaile přátelům.

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["stat"] == "cr")].groupby("rok")["jmeno"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["stat"] == "cr")].groupby("prezident")["jmeno"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='prezident'>

# %% [markdown]
# ## Rozdíly mezi metály

# %%
metaly[metaly["stat"] == "cr"].groupby(["vyznamenani","inmemoriam"])["jmeno"].nunique()
# Out:
# vyznamenani           inmemoriam
# medaile-za-hrdinstvi  False          95
#                       True           42
# medaile-za-zasluhy    False         561
#                       True           73
# rad-bileho-lva        False          74
#                       True           45
# rad-t.-g.-masaryka    False         136
#                       True           51
# Name: jmeno, dtype: int64

# %%
metaly_neboztici = metaly[(metaly["inmemoriam"] == True) & (metaly["stat"] == "cr")].groupby(["vyznamenani"])["jmeno"].nunique() / metaly[metaly["stat"] == "cr"].groupby(["vyznamenani"])["jmeno"].nunique()

# %%
metaly_neboztici
# Out:
# vyznamenani
# medaile-za-hrdinstvi    0.306569
# medaile-za-zasluhy      0.115142
# rad-bileho-lva          0.378151
# rad-t.-g.-masaryka      0.272727
# Name: jmeno, dtype: float64

# %% [markdown]
# ## Není ženské otázky - je otázka lidská (TGM)

# %%
gender = metaly[(metaly["pohlavi"] == "zena")].groupby("rok")["jmeno"].nunique() / metaly.groupby("rok")["jmeno"].nunique()

# %%
gender.plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
pd.DataFrame(metaly[(metaly["stat"] == "cr") & (metaly["pohlavi"] == "zena")].groupby("prezident")["jmeno"].nunique() / metaly[(metaly["stat"] == "cr")].groupby("prezident")["jmeno"].nunique())
# Out:
#               jmeno
# prezident
# Havel      0.120240
# Klaus      0.169173
# Zeman      0.157051

# %%
pd.DataFrame(metaly[(metaly["stat"] == "cr") & (metaly["pohlavi"] == "zena")].groupby("vyznamenani")["jmeno"].nunique() / metaly[(metaly["stat"] == "cr")].groupby("vyznamenani")["jmeno"].nunique())
# Out:
#                          jmeno
# vyznamenani
# medaile-za-hrdinstvi  0.072993
# medaile-za-zasluhy    0.179811
# rad-bileho-lva        0.042017
# rad-t.-g.-masaryka    0.133690

# %% [markdown]
# ## Vícenásobně vyznamenaní

# %%
vicenasobni = pd.DataFrame(metaly.groupby("jmeno")["rok"].nunique().nlargest(45))
vicenasobni = vicenasobni[vicenasobni["rok"] > 1]

poprve = pd.Series(metaly.groupby("jmeno")["rok"].first(), name="poprve")
prvni_prezident = pd.Series(metaly.groupby("jmeno")["prezident"].first(), name="prvni_prezident")
podruhe = pd.Series(metaly.groupby("jmeno")["rok"].last(), name="podruhe")
druhy_prezident = pd.Series(metaly.groupby("jmeno")["prezident"].last(), name="druhy_prezident")
prvni_metal = pd.Series(metaly.groupby("jmeno")["vyznamenani"].first(), name="prvni_metal")
druhy_metal = pd.Series(metaly.groupby("jmeno")["vyznamenani"].last(), name="druhy_metal")
prvni_rank = pd.Series(metaly.groupby("jmeno")["rank"].first(), name="prvni_rank")
druhy_rank = pd.Series(metaly.groupby("jmeno")["rank"].last(), name="druhy_rank")

vicenasobni = vicenasobni.merge(poprve, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(podruhe, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(prvni_prezident, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(druhy_prezident, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(prvni_metal, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(druhy_metal, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(prvni_rank, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(druhy_rank, on="jmeno", how="left")

vicenasobni["rozestup"] = vicenasobni["podruhe"] - vicenasobni["poprve"]

vicenasobni.sort_values(by="rozestup")
# Out:
#                      rok  poprve  podruhe prvni_prezident druhy_prezident  \
# jmeno
# Josef Sedláček         2  1992.0   1996.0         Stráský           Havel
# Viktor Fischl          2  1991.0   1996.0           Havel           Havel
# Radovan Procházka      2  1992.0   1997.0         Stráský           Havel
# Josef Suk              2  1992.0   1999.0         Stráský           Havel
# Jiřina Bohdalová       2  2013.0   2021.0           Zeman           Zeman
# Emil Boček             2  2010.0   2019.0           Klaus           Zeman
# Jaromír Jágr           2  2010.0   2019.0           Klaus           Zeman
# Francois Mitterrand    2  1990.0   1999.0           Havel           Havel
# Jiří Kolář             2  1991.0   2002.0           Havel           Havel
# Karel Gott             2  2009.0   2020.0           Klaus           Zeman
# Alois Šiška            2  1991.0   2003.0           Havel           Klaus
# Hana Hegerová          2  2002.0   2014.0           Havel           Zeman
# Marie Svatošová        2  2002.0   2015.0           Havel           Zeman
# Tomáš Sedláček         2  1991.0   2004.0           Havel           Klaus
# František Fajtl        2  1991.0   2004.0           Havel           Klaus
# Josef Buršík           2  1991.0   2005.0           Havel           Klaus
# Rudolf Pernický        2  1991.0   2005.0           Havel           Klaus
# Stanislav Hlučka       2  1991.0   2005.0           Havel           Klaus
# Erazim Kohák           2  1998.0   2013.0           Havel           Zeman
# Jan Šrámek             2  1991.0   2007.0           Havel           Klaus
# Josef Váňa             2  1992.0   2009.0         Stráský           Klaus
# Josef Veselý           2  1991.0   2009.0           Havel           Klaus
# Jiří Suchý             2  1995.0   2013.0           Havel           Zeman
# Karel Kuttelwascher    2  1998.0   2016.0           Havel           Zeman
# Jan Kačer              2  1998.0   2016.0           Havel           Zeman
# Karel Kryl             2  1995.0   2014.0           Havel           Zeman
# Josef Štemberka        2  1992.0   2014.0         Stráský           Zeman
# Juraj Kukura           2  1992.0   2017.0         Stráský           Zeman
# Karel Kutlvašr         2  1992.0   2017.0         Stráský           Zeman
# Karel Pezl             2  1992.0   2017.0         Stráský           Zeman
# Josef Bílý             2  1992.0   2018.0         Stráský           Zeman
#
#                               prvni_metal         druhy_metal  prvni_rank  \
# jmeno
# Josef Sedláček         medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Viktor Fischl          rad-t.-g.-masaryka  rad-t.-g.-masaryka         3.0
# Radovan Procházka      medaile-za-zasluhy      rad-bileho-lva         1.0
# Josef Suk              medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Jiřina Bohdalová       medaile-za-zasluhy      rad-bileho-lva         1.0
# Emil Boček                 rad-bileho-lva      rad-bileho-lva         3.0
# Jaromír Jágr           medaile-za-zasluhy  medaile-za-zasluhy         2.0
# Francois Mitterrand        rad-bileho-lva      rad-bileho-lva         1.0
# Jiří Kolář             rad-t.-g.-masaryka  medaile-za-zasluhy         2.0
# Karel Gott             medaile-za-zasluhy      rad-bileho-lva         1.0
# Alois Šiška           rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Hana Hegerová          medaile-za-zasluhy  rad-t.-g.-masaryka         3.0
# Marie Svatošová        medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Tomáš Sedláček        rad-m.-r.-stefanika  rad-t.-g.-masaryka         3.0
# František Fajtl       rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Josef Buršík          rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Rudolf Pernický       rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Stanislav Hlučka      rad-m.-r.-stefanika  rad-t.-g.-masaryka         3.0
# Erazim Kohák           medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Jan Šrámek             rad-t.-g.-masaryka  medaile-za-zasluhy         2.0
# Josef Váňa             medaile-za-zasluhy  medaile-za-zasluhy         1.0
# Josef Veselý          rad-m.-r.-stefanika  rad-t.-g.-masaryka         3.0
# Jiří Suchý             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
# Karel Kuttelwascher  medaile-za-hrdinstvi      rad-bileho-lva         1.0
# Jan Kačer              medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Karel Kryl             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
# Josef Štemberka        rad-t.-g.-masaryka  medaile-za-zasluhy         1.0
# Juraj Kukura           medaile-za-zasluhy  medaile-za-zasluhy         1.0
# Karel Kutlvašr        rad-m.-r.-stefanika      rad-bileho-lva         2.0
# Karel Pezl             medaile-za-zasluhy      rad-bileho-lva         1.0
# Josef Bílý            rad-m.-r.-stefanika      rad-bileho-lva         2.0
#
#                      druhy_rank  rozestup
# jmeno
# Josef Sedláček              3.0       4.0
# Viktor Fischl               3.0       5.0
# Radovan Procházka           4.0       5.0
# Josef Suk                   1.0       7.0
# Jiřina Bohdalová            1.0       8.0
# Emil Boček                  1.0       9.0
# Jaromír Jágr                1.0       9.0
# Francois Mitterrand         1.0       9.0
# Jiří Kolář                  2.0      11.0
# Karel Gott                  1.0      11.0
# Alois Šiška                 3.0      12.0
# Hana Hegerová               1.0      12.0
# Marie Svatošová             1.0      13.0
# Tomáš Sedláček              3.0      13.0
# František Fajtl             3.0      13.0
# Josef Buršík                1.0      14.0
# Rudolf Pernický             1.0      14.0
# Stanislav Hlučka            1.0      14.0
# Erazim Kohák                1.0      15.0
# Jan Šrámek                  1.0      16.0
# Josef Váňa                  2.0      17.0
# Josef Veselý                3.0      18.0
# Jiří Suchý                  1.0      18.0
# Karel Kuttelwascher         1.0      18.0
# Jan Kačer                   4.0      18.0
# Karel Kryl                  1.0      19.0
# Josef Štemberka             1.0      22.0
# Juraj Kukura                1.0      25.0
# Karel Kutlvašr              1.0      25.0
# Karel Pezl                  1.0      25.0
# Josef Bílý                  1.0      26.0

# %% [markdown]
# Samostatná ČR – zde již ručně očištěno od jmenovců:

# %%
vicenasobni[vicenasobni["poprve"] > 1992].sort_values(by="rozestup")
# Out:
#                      rok  poprve  podruhe prvni_prezident druhy_prezident  \
# jmeno
# Jiřina Bohdalová       2  2013.0   2021.0           Zeman           Zeman
# Emil Boček             2  2010.0   2019.0           Klaus           Zeman
# Jaromír Jágr           2  2010.0   2019.0           Klaus           Zeman
# Karel Gott             2  2009.0   2020.0           Klaus           Zeman
# Hana Hegerová          2  2002.0   2014.0           Havel           Zeman
# Marie Svatošová        2  2002.0   2015.0           Havel           Zeman
# Erazim Kohák           2  1998.0   2013.0           Havel           Zeman
# Jan Kačer              2  1998.0   2016.0           Havel           Zeman
# Jiří Suchý             2  1995.0   2013.0           Havel           Zeman
# Karel Kuttelwascher    2  1998.0   2016.0           Havel           Zeman
# Karel Kryl             2  1995.0   2014.0           Havel           Zeman
#
#                               prvni_metal         druhy_metal  prvni_rank  \
# jmeno
# Jiřina Bohdalová       medaile-za-zasluhy      rad-bileho-lva         1.0
# Emil Boček                 rad-bileho-lva      rad-bileho-lva         3.0
# Jaromír Jágr           medaile-za-zasluhy  medaile-za-zasluhy         2.0
# Karel Gott             medaile-za-zasluhy      rad-bileho-lva         1.0
# Hana Hegerová          medaile-za-zasluhy  rad-t.-g.-masaryka         3.0
# Marie Svatošová        medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Erazim Kohák           medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Jan Kačer              medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Jiří Suchý             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
# Karel Kuttelwascher  medaile-za-hrdinstvi      rad-bileho-lva         1.0
# Karel Kryl             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
#
#                      druhy_rank  rozestup
# jmeno
# Jiřina Bohdalová            1.0       8.0
# Emil Boček                  1.0       9.0
# Jaromír Jágr                1.0       9.0
# Karel Gott                  1.0      11.0
# Hana Hegerová               1.0      12.0
# Marie Svatošová             1.0      13.0
# Erazim Kohák                1.0      15.0
# Jan Kačer                   4.0      18.0
# Jiří Suchý                  1.0      18.0
# Karel Kuttelwascher         1.0      18.0
# Karel Kryl                  1.0      19.0

# %% [markdown]
# ## Nebožtíci

# %%
metaly[metaly["inmemoriam"] == True].groupby(["rok", "vyznamenani"])["jmeno"].nunique().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
inmemoriamratio = metaly[metaly["inmemoriam"] == True].groupby("rok")["jmeno"].nunique() / metaly.groupby("rok")["jmeno"].nunique()

# %%
inmemoriamratiobezhrdinstvi = metaly[(metaly["inmemoriam"] == True) & (metaly["vyznamenani"] != "medaile-za-hrdinstvi")].groupby("rok")["jmeno"].nunique() / metaly[metaly["vyznamenani"] != "medaile-za-hrdinstvi"].groupby("rok")["jmeno"].nunique()

# %%
inmemoriamratio.plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
inmemoriamratiobezhrdinstvi.plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %% [markdown]
# ## Třídy a stupně

# %%
metaly.groupby(["rok","vyznamenani"])["jmeno"].nunique().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[metaly["rank"] == 1].groupby(["rok"])["jmeno"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly.groupby(["rok","rank"])["jmeno"].nunique().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly.groupby("rank")["jmeno"].nunique()
# Out:
# rank
# 1.0    592
# 2.0    330
# 3.0    343
# 4.0     76
# 5.0      5
# Name: jmeno, dtype: int64

# %% [markdown]
# ## Notabilita Bílých lvů

# %%
lvi_extended = pd.read_csv("lions_e.csv")

# %% [markdown]
# O [notabilitě více zde](https://github.com/michalkasparek/who-Is-who/blob/main/0%20Basic%20Data%20Exploration.ipynb).

# %%
zebricek_podle_vyznamnosti = lvi_extended[lvi_extended["rok"] > 1992].sort_values(by="zebricek")[["rok","jmeno","prezident"]].reset_index().head(25)

# %%
zebricek_podle_vyznamnosti
# Out:
#     index     rok                        jmeno prezident
# 0      93  1999.0                Ronald Reagan     Havel
# 1      11  1998.0    William Jefferson Clinton     Havel
# 2     107  1999.0         Margaret Thatcherová     Havel
# 3      53  1999.0  Michail Sergejevič Gorbačov     Havel
# 4      39  1999.0                  George Bush     Havel
# 5       1  1996.0                  Alžběta II.     Havel
# 6      10  1997.0               Jacques Chirac     Havel
# 7      77  1999.0          François Mitterrand     Havel
# 8      65  1999.0                  Helmut Kohl     Havel
# 9      35  2000.0                 Willy Brandt     Havel
# 10    114  1999.0                  Lech Walesa     Havel
# 11      6  1995.0               Juan Carlos I.     Havel
# 12     57  2003.0                 Václav Havel     Klaus
# 13     83  1998.0             George S. Patton     Havel
# 14     98  2017.0  Gerhard Fritz Kurt Schröder     Zeman
# 15     82  2000.0           Olof Joachim Palme     Havel
# 16     31  1997.0     Madeleine K. Albrightová     Havel
# 17    116  1999.0             Simon Wiesenthal     Havel
# 18      0  2015.0  Abdullah II. bin Al Hussein     Zeman
# 19    115  2003.0       Richard von Weizsäcker     Klaus
# 20     44  2003.0             Alexander Dubček     Klaus
# 21     16  2014.0                Joachim Gauck     Zeman
# 22     23  2019.0                 Václav Klaus     Zeman
# 23     27  2000.0                 Johannes Rau     Havel
# 24     69  2000.0                Bruno Kreisky     Havel

# %%
zebricek_podle_vyznamnosti.to_csv("zebricek_podle_vyznamnosti.csv")

# %%
lvi_extended[lvi_extended["zebricek"] < 1001].groupby("rok")["jmeno"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
lvi_extended[(lvi_extended["zebricek"] < 1001) & (lvi_extended["rok"] == 1999)]
# Out:
#     stat     vyznamenani                        jmeno  vyznamnost  zebricek  \
# 39    cr  rad-bileho-lva                  George Bush   38.091080     178.0
# 53    cr  rad-bileho-lva  Michail Sergejevič Gorbačov   37.324436     147.0
# 65    cr  rad-bileho-lva                  Helmut Kohl   35.460560     612.0
# 77    cr  rad-bileho-lva          François Mitterrand   35.902332     470.0
# 93    cr  rad-bileho-lva                Ronald Reagan   39.705551      20.0
# 107   cr  rad-bileho-lva         Margaret Thatcherová   38.070229     144.0
# 114   cr  rad-bileho-lva                  Lech Walesa   35.411781     801.5
#
#      narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 39     1924.0  2018.0  1999.0   1.0  False  občanská       False     muz
# 53     1931.0  2022.0  1999.0   1.0  False  občanská       False     muz
# 65     1930.0  2017.0  1999.0   1.0  False  občanská       False     muz
# 77     1916.0  1996.0  1999.0   1.0  False  občanská        True     muz
# 93     1911.0  2004.0  1999.0   1.0  False  občanská       False     muz
# 107    1925.0  2013.0  1999.0   1.0  False  občanská       False    zena
# 114    1943.0     NaN  1999.0   1.0  False  občanská       False     muz
#
#     prezident
# 39      Havel
# 53      Havel
# 65      Havel
# 77      Havel
# 93      Havel
# 107     Havel
# 114     Havel

# %%
pd.DataFrame(lvi_extended.sort_values(by="zebricek").groupby("rok")["jmeno"].first())
# Out:
#                               jmeno
# rok
# 1990.0          François Mitterrand
# 1992.0               H. G. Skilling
# 1995.0               Juan Carlos I.
# 1996.0                  Alžběta II.
# 1997.0               Jacques Chirac
# 1998.0    William Jefferson Clinton
# 1999.0                Ronald Reagan
# 2000.0                 Willy Brandt
# 2002.0              Guido Venturoni
# 2003.0                 Václav Havel
# 2004.0       Aleksander Kwasniewsky
# 2005.0                 Josef Buršík
# 2006.0                  Josef Bryks
# 2007.0           Stanislav Hnělička
# 2008.0                Jiří Zenáhlík
# 2009.0                Heinz Fischer
# 2010.0    Lech Aleksander Kaczyński
# 2011.0                Václav Djačuk
# 2012.0               Alexander Beer
# 2013.0              Ivan Gašparovič
# 2014.0                Joachim Gauck
# 2015.0  Abdullah II. bin Al Hussein
# 2016.0                 Andrzej Duda
# 2017.0  Gerhard Fritz Kurt Schröder
# 2018.0               Antonín Švehla
# 2019.0                 Václav Klaus
# 2020.0                   Karel Gott
# 2021.0           Alfred Duff Cooper

# %%
lvi_extended["vek"] = lvi_extended["rok"] - lvi_extended["narozeni"]

# %%
lvi_extended[lvi_extended["inmemoriam"] == False].sort_values(by="vek").head(5)
# Out:
#    stat     vyznamenani                        jmeno  vyznamnost  zebricek  \
# 9    cr  rad-bileho-lva                 Andrzej Duda   32.687565   11227.0
# 24   cr  rad-bileho-lva       Aleksander Kwasniewsky   31.260067   12352.0
# 11   cr  rad-bileho-lva    William Jefferson Clinton   38.609379      46.0
# 0    cr  rad-bileho-lva  Abdullah II. bin Al Hussein   34.551716    1917.0
# 26   cr  rad-bileho-lva                  Borut Pahor   30.235401   30551.0
#
#     narozeni  umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 9     1972.0    NaN  2016.0   1.0   True  občanská       False     muz
# 24    1954.0    NaN  2004.0   1.0   True  občanská       False     muz
# 11    1946.0    NaN  1998.0   1.0   True  občanská       False     muz
# 0     1962.0    NaN  2015.0   1.0   True  občanská       False     muz
# 26    1963.0    NaN  2017.0   1.0   True  občanská       False     muz
#
#    prezident   vek
# 9      Zeman  44.0
# 24     Klaus  50.0
# 11     Havel  52.0
# 0      Zeman  53.0
# 26     Zeman  54.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == False].sort_values(by="vek").tail(5)
# Out:
#    stat     vyznamenani              jmeno  vyznamnost  zebricek  narozeni  \
# 25   cr  rad-bileho-lva       Karel Lánský         NaN       NaN    1924.0
# 50   cr  rad-bileho-lva     Imrich Gablech   19.191671  705058.0    1915.0
# 33   cr  rad-bileho-lva     Alexander Beer         NaN       NaN    1917.0
# 4    cr  rad-bileho-lva         Emil Boček         NaN       NaN    1923.0
# 75   cr  rad-bileho-lva  Jindřich Macháček         NaN       NaN       NaN
#
#      umrti     rok  rank  retez   skupina  inmemoriam pohlavi prezident   vek
# 25  2019.0  2018.0   1.0  False  občanská       False     muz     Zeman  94.0
# 50  2016.0  2009.0   3.0  False  vojenská       False     muz     Klaus  94.0
# 33  2015.0  2012.0   2.0  False  vojenská       False     muz     Klaus  95.0
# 4      NaN  2019.0   1.0  False  vojenská       False     muz     Zeman  96.0
# 75     NaN  1997.0   4.0  False  vojenská       False     muz     Havel   NaN

# %%
lvi_extended["posmrti"] = lvi_extended["rok"] - lvi_extended["umrti"]

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].sort_values(by="posmrti").head(10)
# Out:
#     stat     vyznamenani                      jmeno  vyznamnost  zebricek  \
# 105   cr  rad-bileho-lva                Alois Šiška         NaN       NaN
# 40    cr  rad-bileho-lva               Otakar Černý         NaN       NaN
# 71    cr  rad-bileho-lva       Rudolf Severin Krzák   17.960215  868324.5
# 21    cr  rad-bileho-lva  Lech Aleksander Kaczyński   33.079590    6440.5
# 22    cr  rad-bileho-lva               Petr Kellner   25.452185  431490.0
# 62    cr  rad-bileho-lva               Josef Hyhlík         NaN       NaN
# 17    cr  rad-bileho-lva                 Karel Gott   31.278296    8761.0
# 77    cr  rad-bileho-lva        François Mitterrand   35.902332     470.0
# 38    cr  rad-bileho-lva               Josef Buršík   22.357090  280977.5
# 35    cr  rad-bileho-lva               Willy Brandt   35.375935     633.0
#
#      narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 105    1914.0  2003.0  2003.0   3.0  False  vojenská        True     muz
# 40     1919.0  2009.0  2009.0   1.0  False  vojenská        True     muz
# 71     1914.0  2004.0  2004.0   3.0  False  vojenská        True     muz
# 21     1949.0  2010.0  2010.0   1.0   True  občanská        True     muz
# 22     1964.0  2021.0  2021.0   1.0  False  občanská        True     muz
# 62     1922.0  1997.0  1998.0   3.0  False  občanská        True     muz
# 17     1939.0  2019.0  2020.0   1.0  False  občanská        True     muz
# 77     1916.0  1996.0  1999.0   1.0  False  občanská        True     muz
# 38     1911.0  2002.0  2005.0   1.0  False  vojenská        True     muz
# 35     1913.0  1992.0  2000.0   1.0  False  občanská        True     muz
#
#     prezident   vek  posmrti
# 105     Klaus  89.0      0.0
# 40      Klaus  90.0      0.0
# 71      Klaus  90.0      0.0
# 21      Klaus  61.0      0.0
# 22      Zeman  57.0      0.0
# 62      Havel  76.0      1.0
# 17      Zeman  81.0      1.0
# 77      Havel  83.0      3.0
# 38      Klaus  94.0      3.0
# 35      Havel  87.0      8.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].sort_values(by="posmrti").tail(5)
# Out:
#    stat     vyznamenani            jmeno  vyznamnost  zebricek  narozeni  \
# 81   cr  rad-bileho-lva     Josef Ocelka         NaN       NaN    1909.0
# 3    cr  rad-bileho-lva       Josef Bílý   20.048971  627090.0    1872.0
# 29   cr  rad-bileho-lva   Antonín Švehla   26.397543   63483.0    1873.0
# 7    cr  rad-bileho-lva  Stanislav Čeček   21.707483  427032.0    1886.0
# 49   cr  rad-bileho-lva      Robert Fico   30.919975   15775.5    1964.0
#
#      umrti     rok  rank  retez   skupina  inmemoriam pohlavi prezident  \
# 81  1942.0  2019.0   1.0  False  vojenská        True     muz     Zeman
# 3   1941.0  2018.0   1.0  False  vojenská        True     muz     Zeman
# 29  1933.0  2018.0   1.0  False  občanská        True     muz     Zeman
# 7   1930.0  2018.0   1.0  False  vojenská        True     muz     Zeman
# 49     NaN  2014.0   1.0  False  občanská        True     muz     Zeman
#
#       vek  posmrti
# 81  110.0     77.0
# 3   146.0     77.0
# 29  145.0     85.0
# 7   132.0     88.0
# 49   50.0      NaN

# %%
lvi_extended[lvi_extended["inmemoriam"] == True]["posmrti"].median()
# Out:
# 37.5

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].sort_values(by="umrti").head(5)
# Out:
#    stat     vyznamenani            jmeno  vyznamnost  zebricek  narozeni  \
# 7    cr  rad-bileho-lva  Stanislav Čeček   21.707483  427032.0    1886.0
# 29   cr  rad-bileho-lva   Antonín Švehla   26.397543   63483.0    1873.0
# 3    cr  rad-bileho-lva       Josef Bílý   20.048971  627090.0    1872.0
# 47   cr  rad-bileho-lva      Alois Eliáš   27.110500   51954.0    1890.0
# 81   cr  rad-bileho-lva     Josef Ocelka         NaN       NaN    1909.0
#
#      umrti     rok  rank  retez   skupina  inmemoriam pohlavi prezident  \
# 7   1930.0  2018.0   1.0  False  vojenská        True     muz     Zeman
# 29  1933.0  2018.0   1.0  False  občanská        True     muz     Zeman
# 3   1941.0  2018.0   1.0  False  vojenská        True     muz     Zeman
# 47  1942.0  1996.0   1.0  False  vojenská        True     muz     Havel
# 81  1942.0  2019.0   1.0  False  vojenská        True     muz     Zeman
#
#       vek  posmrti
# 7   132.0     88.0
# 29  145.0     85.0
# 3   146.0     77.0
# 47  106.0     54.0
# 81  110.0     77.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == False].sort_values(by="posmrti").head(5)
# Out:
#      stat     vyznamenani                        jmeno  vyznamnost  zebricek  \
# 1      cr  rad-bileho-lva                  Alžběta II.   39.511745     419.0
# 31     cr  rad-bileho-lva     Madeleine K. Albrightová   34.017853    1688.0
# 91     cr  rad-bileho-lva            Radovan Procházka         NaN       NaN
# 53     cr  rad-bileho-lva  Michail Sergejevič Gorbačov   37.324436     147.0
# 124  csfr  rad-bileho-lva              Josef Škvorecký   28.360466   24888.0
#
#      narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 1      1926.0  2022.0  1996.0   1.0   True  občanská       False    zena
# 31     1937.0  2022.0  1997.0   1.0  False  občanská       False    zena
# 91     1927.0  2020.0  1997.0   4.0  False  vojenská       False     muz
# 53     1931.0  2022.0  1999.0   1.0  False  občanská       False     muz
# 124    1924.0  2012.0  1990.0   3.0  False       NaN       False     muz
#
#     prezident   vek  posmrti
# 1       Havel  70.0    -26.0
# 31      Havel  60.0    -25.0
# 91      Havel  70.0    -23.0
# 53      Havel  68.0    -23.0
# 124     Havel  66.0    -22.0

# %%
lvi_extended[(lvi_extended["inmemoriam"] == False) & lvi_extended.posmrti.notnull()].sort_values(by="posmrti").tail(20)
# Out:
#      stat     vyznamenani                      jmeno  vyznamnost  zebricek  \
# 36     cr  rad-bileho-lva                   Jan Bret         NaN       NaN
# 116    cr  rad-bileho-lva           Simon Wiesenthal   33.570942    1793.0
# 120  csfr  rad-bileho-lva        François Mitterrand   35.902332     470.0
# 27     cr  rad-bileho-lva               Johannes Rau   31.696262    5823.0
# 87     cr  rad-bileho-lva               Anton Petrák         NaN       NaN
# 93     cr  rad-bileho-lva              Ronald Reagan   39.705551      20.0
# 109    cr  rad-bileho-lva                  Jan Velík         NaN       NaN
# 66     cr  rad-bileho-lva           Miluláš Končický         NaN       NaN
# 42     cr  rad-bileho-lva              Václav Djačuk         NaN       NaN
# 67     cr  rad-bileho-lva                Vasil Korol         NaN       NaN
# 33     cr  rad-bileho-lva             Alexander Beer         NaN       NaN
# 92     cr  rad-bileho-lva         Pravomil L. Raichl         NaN       NaN
# 48     cr  rad-bileho-lva            František Fajtl   24.466726  122172.0
# 90     cr  rad-bileho-lva         Karel J. Procházka         NaN       NaN
# 106    cr  rad-bileho-lva             Antonín Špaček         NaN       NaN
# 25     cr  rad-bileho-lva               Karel Lánský         NaN       NaN
# 74     cr  rad-bileho-lva  Marie Ljalková-Lastovecká   23.347412  478653.5
# 84     cr  rad-bileho-lva            Rudolf Pernický   19.767851  584814.5
# 94     cr  rad-bileho-lva              Josef Robotka         NaN       NaN
# 121  csfr  rad-bileho-lva           Vladimír Krajina   22.397926  240550.0
#
#      narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 36     1923.0  2002.0  1995.0   3.0  False  vojenská       False     muz
# 116    1908.0  2005.0  1999.0   3.0  False  občanská       False     muz
# 120    1916.0  1996.0  1990.0   1.0  False       NaN       False     muz
# 27     1931.0  2006.0  2000.0   1.0   True  občanská       False     muz
# 87     1912.0  2009.0  2003.0   1.0  False  vojenská       False     muz
# 93     1911.0  2004.0  1999.0   1.0  False  občanská       False     muz
# 109    1921.0  2016.0  2011.0   2.0  False  vojenská       False     muz
# 66     1925.0  2015.0  2011.0   2.0  False  vojenská       False     muz
# 42     1920.0  2015.0  2011.0   5.0  False  vojenská       False     muz
# 67     1922.0  2015.0  2012.0   4.0  False  vojenská       False     muz
# 33     1917.0  2015.0  2012.0   2.0  False  vojenská       False     muz
# 92     1921.0  2002.0  2000.0   5.0  False  vojenská       False     muz
# 48     1912.0  2006.0  2004.0   3.0  False  vojenská       False     muz
# 90     1905.0  1999.0  1997.0   4.0  False  vojenská       False     muz
# 106    1917.0  2007.0  2006.0   1.0  False  vojenská       False     muz
# 25     1924.0  2019.0  2018.0   1.0  False  občanská       False     muz
# 74     1920.0  2011.0  2010.0   2.0  False  vojenská       False    zena
# 84     1915.0  2005.0  2005.0   1.0  False  vojenská       False     muz
# 94     1906.0  1952.0  1997.0   3.0  False  vojenská       False     muz
# 121    1905.0  1933.0  1990.0   1.0  False       NaN       False     muz
#
#     prezident   vek  posmrti
# 36      Havel  72.0     -7.0
# 116     Havel  91.0     -6.0
# 120     Havel  74.0     -6.0
# 27      Havel  69.0     -6.0
# 87      Klaus  91.0     -6.0
# 93      Havel  88.0     -5.0
# 109     Klaus  90.0     -5.0
# 66      Klaus  86.0     -4.0
# 42      Klaus  91.0     -4.0
# 67      Klaus  90.0     -3.0
# 33      Klaus  95.0     -3.0
# 92      Havel  79.0     -2.0
# 48      Klaus  92.0     -2.0
# 90      Havel  92.0     -2.0
# 106     Klaus  89.0     -1.0
# 25      Zeman  94.0     -1.0
# 74      Klaus  90.0     -1.0
# 84      Klaus  90.0      0.0
# 94      Havel  91.0     45.0
# 121     Havel  85.0     57.0

# %% [markdown]
# Jen pár týdnů se z ŘBL těšil Rudolf Pernický: V letech 1990 až 1992 byl předsedou Konfederace politických vězňů a poté byl jejím čestným předsedou. Poslední roky svého života trávil v Domově pro válečné veterány a i přes své chatrné zdraví (dlouhodobé problémy s cukrovkou) se v posledním roce pustil do boje proti zrušení tohoto útočiště pro válečné veterány. Svou bojovnost projevil i během předávání nejvyššího státního vyznamenání Řádu Bílého lva na podzim 2005, kam se osobně dostavil přesto, že se o dva týdny dříve musel podrobit složité operaci – amputaci nohou.[3]

# %%
lvi_extended.sort_values(by="zebricek").tail(60)
# Out:
#      stat     vyznamenani                      jmeno     vyznamnost  \
# 22     cr  rad-bileho-lva               Petr Kellner      25.452185
# 74     cr  rad-bileho-lva  Marie Ljalková-Lastovecká      23.347412
# 123  csfr  rad-bileho-lva             H. G. Skilling      20.104029
# 72     cr  rad-bileho-lva             Karel Kutlvašr      21.398306
# 56     cr  rad-bileho-lva                 Paul Hatry  507605.000000
# 70     cr  rad-bileho-lva              Ludvík Krejčí      20.644863
# 84     cr  rad-bileho-lva            Rudolf Pernický      19.767851
# 3      cr  rad-bileho-lva                 Josef Bílý      20.048971
# 60     cr  rad-bileho-lva             Bedřich Homola      19.372997
# 50     cr  rad-bileho-lva             Imrich Gablech      19.191671
# 88     cr  rad-bileho-lva                 Karel Pezl      18.834990
# 32     cr  rad-bileho-lva               Josef Bartík      18.353737
# 79     cr  rad-bileho-lva            Vladimír Nedvěd      18.147558
# 71     cr  rad-bileho-lva       Rudolf Severin Krzák      17.960215
# 110    cr  rad-bileho-lva            Guido Venturoni      19.899698
# 64     cr  rad-bileho-lva             Miroslav Kácha      17.734098
# 117    cr  rad-bileho-lva          Thomas Ray Wilson      18.984396
# 4      cr  rad-bileho-lva                 Emil Boček            NaN
# 12     cr  rad-bileho-lva              Bohuslav Ečer            NaN
# 18     cr  rad-bileho-lva             Alexander Hess            NaN
# 19     cr  rad-bileho-lva     v.v. František Chábera            NaN
# 20     cr  rad-bileho-lva              Karel Husárek            NaN
# 25     cr  rad-bileho-lva               Karel Lánský            NaN
# 33     cr  rad-bileho-lva             Alexander Beer            NaN
# 34     cr  rad-bileho-lva                 Emil Boček            NaN
# 36     cr  rad-bileho-lva                   Jan Bret            NaN
# 40     cr  rad-bileho-lva               Otakar Černý            NaN
# 41     cr  rad-bileho-lva       Antonín Mikuláš Číla            NaN
# 42     cr  rad-bileho-lva              Václav Djačuk            NaN
# 45     cr  rad-bileho-lva                 Josef Duda            NaN
# 52     cr  rad-bileho-lva          Vladimír Garncarz            NaN
# 55     cr  rad-bileho-lva              Antonín Hasal            NaN
# 59     cr  rad-bileho-lva         Stanislav Hnělička            NaN
# 61     cr  rad-bileho-lva              Rudolf Hrubec            NaN
# 62     cr  rad-bileho-lva               Josef Hyhlík            NaN
# 66     cr  rad-bileho-lva           Miluláš Končický            NaN
# 67     cr  rad-bileho-lva                Vasil Korol            NaN
# 68     cr  rad-bileho-lva            Jaroslav Krátký            NaN
# 75     cr  rad-bileho-lva          Jindřich Macháček            NaN
# 80     cr  rad-bileho-lva            Bedřich Neumann            NaN
# 81     cr  rad-bileho-lva               Josef Ocelka            NaN
# 86     cr  rad-bileho-lva                Felix Peřka            NaN
# 87     cr  rad-bileho-lva               Anton Petrák            NaN
# 89     cr  rad-bileho-lva               Jan Plovajko            NaN
# 90     cr  rad-bileho-lva         Karel J. Procházka            NaN
# 91     cr  rad-bileho-lva          Radovan Procházka            NaN
# 92     cr  rad-bileho-lva         Pravomil L. Raichl            NaN
# 94     cr  rad-bileho-lva              Josef Robotka            NaN
# 95     cr  rad-bileho-lva               Chanan Rozen            NaN
# 97     cr  rad-bileho-lva            Jaroslav Selner            NaN
# 100    cr  rad-bileho-lva             Oldřich Skácel            NaN
# 101    cr  rad-bileho-lva         František Slunečko            NaN
# 103    cr  rad-bileho-lva            Vilém Stanovský            NaN
# 104    cr  rad-bileho-lva                Oto Stehlík            NaN
# 105    cr  rad-bileho-lva                Alois Šiška            NaN
# 106    cr  rad-bileho-lva             Antonín Špaček            NaN
# 109    cr  rad-bileho-lva                  Jan Velík            NaN
# 111    cr  rad-bileho-lva        Sergej Vojcechovský            NaN
# 113    cr  rad-bileho-lva              Veleslav Wahl            NaN
# 118    cr  rad-bileho-lva              Jiří Zenáhlík            NaN
#
#       zebricek  narozeni   umrti     rok  rank  retez   skupina  inmemoriam  \
# 22    431490.0    1964.0  2021.0  2021.0   1.0  False  občanská        True
# 74    478653.5    1920.0  2011.0  2010.0   2.0  False  vojenská       False
# 123   495709.5    1912.0  2001.0  1992.0   3.0  False       NaN       False
# 72    499605.0    1895.0  1961.0  2017.0   1.0  False  vojenská        True
# 56    507605.0    1929.0  2010.0  1998.0   3.0  False  občanská       False
# 70    512313.0    1890.0  1972.0  2017.0   1.0  False  vojenská        True
# 84    584814.5    1915.0  2005.0  2005.0   1.0  False  vojenská       False
# 3     627090.0    1872.0  1941.0  2018.0   1.0  False  vojenská        True
# 60    638016.5    1887.0  1943.0  1998.0   2.0  False  vojenská        True
# 50    705058.0    1915.0  2016.0  2009.0   3.0  False  vojenská       False
# 88    770032.0    1927.0     NaN  2017.0   1.0  False  vojenská       False
# 32    830617.0    1897.0  1968.0  1998.0   3.0  False  vojenská        True
# 79    863368.0    1917.0  2012.0  1996.0   3.0  False  vojenská       False
# 71    868324.5    1914.0  2004.0  2004.0   3.0  False  vojenská        True
# 110   900010.0    1934.0     NaN  2002.0   3.0  False  občanská       False
# 64   1000308.0    1923.0  2010.0  1995.0   3.0  False  vojenská       False
# 117  1397787.0    1946.0     NaN  2002.0   3.0  False  občanská       False
# 4          NaN    1923.0     NaN  2019.0   1.0  False  vojenská       False
# 12         NaN    1893.0  1954.0  2019.0   1.0  False  vojenská        True
# 18         NaN    1898.0  1981.0  2021.0   1.0  False  vojenská        True
# 19         NaN    1912.0  1999.0  2020.0   1.0  False  vojenská        True
# 20         NaN    1893.0  1972.0  2018.0   1.0  False  vojenská        True
# 25         NaN    1924.0  2019.0  2018.0   1.0  False  občanská       False
# 33         NaN    1917.0  2015.0  2012.0   2.0  False  vojenská       False
# 34         NaN    1923.0     NaN  2010.0   3.0  False  vojenská       False
# 36         NaN    1923.0  2002.0  1995.0   3.0  False  vojenská       False
# 40         NaN    1919.0  2009.0  2009.0   1.0  False  vojenská        True
# 41         NaN    1883.0  1983.0  1998.0   2.0  False  vojenská        True
# 42         NaN    1920.0  2015.0  2011.0   5.0  False  vojenská       False
# 45         NaN    1905.0  1977.0  2002.0   3.0  False  vojenská        True
# 52         NaN    1924.0  2004.0  1995.0   3.0  False  vojenská       False
# 55         NaN    1893.0  1960.0  1995.0   2.0  False  vojenská        True
# 59         NaN    1922.0  2016.0  2007.0   2.0  False  vojenská       False
# 61         NaN    1914.0  1944.0  2007.0   1.0  False  vojenská        True
# 62         NaN    1922.0  1997.0  1998.0   3.0  False  občanská        True
# 66         NaN    1925.0  2015.0  2011.0   2.0  False  vojenská       False
# 67         NaN    1922.0  2015.0  2012.0   4.0  False  vojenská       False
# 68         NaN    1911.0  1945.0  1998.0   4.0  False  vojenská        True
# 75         NaN       NaN     NaN  1997.0   4.0  False  vojenská       False
# 80         NaN    1981.0  1964.0  1997.0   3.0  False  vojenská        True
# 81         NaN    1909.0  1942.0  2019.0   1.0  False  vojenská        True
# 86         NaN    1924.0  2005.0  1995.0   3.0  False  vojenská       False
# 87         NaN    1912.0  2009.0  2003.0   1.0  False  vojenská       False
# 89         NaN    1922.0  2020.0  2010.0   3.0  False  vojenská       False
# 90         NaN    1905.0  1999.0  1997.0   4.0  False  vojenská       False
# 91         NaN    1927.0  2020.0  1997.0   4.0  False  vojenská       False
# 92         NaN    1921.0  2002.0  2000.0   5.0  False  vojenská       False
# 94         NaN    1906.0  1952.0  1997.0   3.0  False  vojenská       False
# 95         NaN    1918.0  2013.0  1998.0   4.0  False  občanská       False
# 97         NaN    1906.0  1973.0  2019.0   1.0  False  vojenská        True
# 100        NaN    1908.0  2002.0  1995.0   3.0  False  vojenská       False
# 101        NaN    1886.0  1963.0  1998.0   3.0  False  vojenská        True
# 103        NaN    1896.0  1972.0  2000.0   3.0  False  vojenská        True
# 104        NaN    1924.0     NaN  2002.0   4.0  False  občanská       False
# 105        NaN    1914.0  2003.0  2003.0   3.0  False  vojenská        True
# 106        NaN    1917.0  2007.0  2006.0   1.0  False  vojenská       False
# 109        NaN    1921.0  2016.0  2011.0   2.0  False  vojenská       False
# 111        NaN    1883.0  1951.0  1997.0   3.0  False  vojenská        True
# 113        NaN    1922.0  1950.0  1995.0   2.0  False  občanská        True
# 118        NaN    1921.0     NaN  2008.0   1.0  False  vojenská       False
#
#     pohlavi prezident    vek  posmrti
# 22      muz     Zeman   57.0      0.0
# 74     zena     Klaus   90.0     -1.0
# 123     muz   Stráský   80.0     -9.0
# 72      muz     Zeman  122.0     56.0
# 56      muz     Havel   69.0    -12.0
# 70      muz     Zeman  127.0     45.0
# 84      muz     Klaus   90.0      0.0
# 3       muz     Zeman  146.0     77.0
# 60      muz     Havel  111.0     55.0
# 50      muz     Klaus   94.0     -7.0
# 88      muz     Zeman   90.0      NaN
# 32      muz     Havel  101.0     30.0
# 79      muz     Havel   79.0    -16.0
# 71      muz     Klaus   90.0      0.0
# 110     muz     Havel   68.0      NaN
# 64      muz     Havel   72.0    -15.0
# 117     muz     Havel   56.0      NaN
# 4       muz     Zeman   96.0      NaN
# 12      muz     Zeman  126.0     65.0
# 18      muz     Zeman  123.0     40.0
# 19      muz     Zeman  108.0     21.0
# 20      muz     Zeman  125.0     46.0
# 25      muz     Zeman   94.0     -1.0
# 33      muz     Klaus   95.0     -3.0
# 34      muz     Klaus   87.0      NaN
# 36      muz     Havel   72.0     -7.0
# 40      muz     Klaus   90.0      0.0
# 41      muz     Havel  115.0     15.0
# 42      muz     Klaus   91.0     -4.0
# 45      muz     Havel   97.0     25.0
# 52      muz     Havel   71.0     -9.0
# 55      muz     Havel  102.0     35.0
# 59      muz     Klaus   85.0     -9.0
# 61      muz     Klaus   93.0     63.0
# 62      muz     Havel   76.0      1.0
# 66      muz     Klaus   86.0     -4.0
# 67      muz     Klaus   90.0     -3.0
# 68      muz     Havel   87.0     53.0
# 75      muz     Havel    NaN      NaN
# 80      muz     Havel   16.0     33.0
# 81      muz     Zeman  110.0     77.0
# 86      muz     Havel   71.0    -10.0
# 87      muz     Klaus   91.0     -6.0
# 89      muz     Klaus   88.0    -10.0
# 90      muz     Havel   92.0     -2.0
# 91      muz     Havel   70.0    -23.0
# 92      muz     Havel   79.0     -2.0
# 94      muz     Havel   91.0     45.0
# 95      muz     Havel   80.0    -15.0
# 97      muz     Zeman  113.0     46.0
# 100     muz     Havel   87.0     -7.0
# 101     muz     Havel  112.0     35.0
# 103     muz     Havel  104.0     28.0
# 104     muz     Havel   78.0      NaN
# 105     muz     Klaus   89.0      0.0
# 106     muz     Klaus   89.0     -1.0
# 109     muz     Klaus   90.0     -5.0
# 111     muz     Havel  114.0     46.0
# 113     muz     Havel   73.0     45.0
# 118     muz     Klaus   87.0      NaN

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].groupby("prezident")["posmrti"].median()
# Out:
# prezident
# Havel    31.5
# Klaus     1.5
# Zeman    55.0
# Name: posmrti, dtype: float64

# %% [markdown]
# Když už dával Klaus in memoriam, bylo to čerstvě zesnulým.

# %% [markdown]
# ## Syntéza

# %%
synt_zeny = pd.Series(metaly[(metaly["stat"] == "cr") & (metaly["pohlavi"] == "zena")].groupby("prezident")["jmeno"].nunique() / metaly[metaly["stat"] == "cr"].groupby("prezident")["jmeno"].nunique(), name="zeny")

synt_prvnitridy = pd.Series(metaly[(metaly["stat"] == "cr") & (metaly["rank"] == 1)].groupby("prezident")["jmeno"].nunique() / metaly[metaly["stat"] == "cr"].groupby("prezident")["jmeno"].nunique(), name="prvni tridy a stupne")

synt_inmemoriam = pd.Series(metaly[(metaly["stat"] == "cr") & (metaly["inmemoriam"] == True)].groupby("prezident")["jmeno"].nunique() / metaly[metaly["stat"] == "cr"].groupby("prezident")["jmeno"].nunique(), name="in memoriam")

synt_vyznamni1000_zivi = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["zebricek"] < 1000) & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["jmeno"].nunique() / lvi_extended[(lvi_extended["stat"] == "cr")  & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["jmeno"].nunique(), name="tisicovka nejvyznamejsich lidi, bez in memoriam")

synt_vyznamni100000_zivi = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["zebricek"] < 100000) & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["jmeno"].nunique() / lvi_extended[(lvi_extended["stat"] == "cr")  & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["jmeno"].nunique(), name="sto tisic nejvyznamejsich lidi, bez in memoriam")

# %%
synt2_inmemoriam_rekord = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["inmemoriam"] == True)].groupby("prezident")["posmrti"].max(), name="in memoriam ŘBL nejdele po smrti")
synt2_inmemoriam_median = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["inmemoriam"] == True)].groupby("prezident")["posmrti"].median(), name="in memoriam ŘBL medián")

# %%
synteza = pd.DataFrame(index=["Havel","Klaus","Zeman"])
synteza = synteza.merge(synt_zeny.to_frame(), left_index=True, right_index=True)
synteza = synteza.merge(synt_prvnitridy.to_frame(), left_index=True, right_index=True)
synteza = synteza.merge(synt_inmemoriam.to_frame(), left_index=True, right_index=True)
synteza = synteza.merge(synt_vyznamni1000_zivi.to_frame(), left_index=True, right_index=True)

# %%
synteza2 = pd.DataFrame(index=["Havel","Klaus","Zeman"])
synteza2 = synteza2.merge(synt2_inmemoriam_median.to_frame(), left_index=True, right_index=True)
synteza2 = synteza2.merge(synt2_inmemoriam_rekord.to_frame(), left_index=True, right_index=True)

# %%
synteza
# Out:
#            zeny  prvni tridy a stupne  in memoriam  \
# Havel  0.120240              0.374749     0.230461
# Klaus  0.169173              0.259398     0.090226
# Zeman  0.157051              0.868590     0.230769
#
#        tisicovka nejvyznamejsich lidi, bez in memoriam
# Havel                                         0.236842
# Klaus                                              NaN
# Zeman                                              NaN

# %%
synteza2
# Out:
#        in memoriam ŘBL medián  in memoriam ŘBL nejdele po smrti
# Havel                    31.5                              55.0
# Klaus                     1.5                              63.0
# Zeman                    55.0                              88.0

# %%
synteza.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ⬆️GRAF2a

# %%
synteza2.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ⬆️GRAF2b: Rád bych ty prezidenty porovnal takhle na přímo, ideálně jedním grafem, jenže na ose Y se pohybujeme v jiných řádech/jednotkách: procenta vs. roky (a ty roky jsou v rozpětí 1,5 až 88).

# %% [markdown]
# ## Strojovna – není nutné studovat

# %%
jmena = metaly["jmeno"].sort_values().drop_duplicates().to_list()

# %%
with open("jmena" + ".txt", 'w+', encoding="utf-8") as seznam:
    seznam.write(str("\n".join(jmena)))

# %%
lions = metaly[metaly["vyznamenani"] == "rad-bileho-lva"]

# %%
lions.to_csv("lions.csv", index=False)

# %%
metaly.to_csv("export.csv", index=False)

# %%
metaly[(metaly["vyznamenani"] == "rad-t.-g.-masaryka") & (metaly["inmemoriam"] == True)].sort_values(by="rok",ascending=True)
# Out:
#      stat         vyznamenani              jmeno     rok  rank  retez skupina  \
# 167  csfr  rad-t.-g.-masaryka      Josef Zvěřina  1991.0   2.0  False     NaN
# 55   csfr  rad-t.-g.-masaryka       Ján Jesenský  1991.0   4.0  False     NaN
# 56   csfr  rad-t.-g.-masaryka     Dušan Jurkovič  1991.0   1.0  False     NaN
# 57   csfr  rad-t.-g.-masaryka     Záviš Kalandra  1991.0   1.0  False     NaN
# 58   csfr  rad-t.-g.-masaryka     Zdeněk Kalista  1991.0   1.0  False     NaN
# ..    ...                 ...                ...     ...   ...    ...     ...
# 18     cr  rad-t.-g.-masaryka     Charles Craine  2017.0   1.0  False     nan
# 127    cr  rad-t.-g.-masaryka       Jože Plečnik  2017.0   1.0  False     nan
# 25     cr  rad-t.-g.-masaryka      Rajko Doleček  2018.0   1.0  False     nan
# 71     cr  rad-t.-g.-masaryka  pplk. Jan Jelínek  2019.0   1.0  False     nan
# 135    cr  rad-t.-g.-masaryka    Karel Raška II.  2021.0   1.0  False     nan
#
#      inmemoriam pohlavi prezident
# 167        True     muz     Havel
# 55         True     muz     Havel
# 56         True     muz     Havel
# 57         True     muz     Havel
# 58         True     muz     Havel
# ..          ...     ...       ...
# 18         True     muz     Zeman
# 127        True     muz     Zeman
# 25         True     muz     Zeman
# 71         True     muz     Zeman
# 135        True     muz     Zeman
#
# [184 rows x 10 columns]

# %%
lvi_extended.groupby("umrti")["jmeno"].nunique().nlargest(10)
# Out:
# umrti
# 2015.0    6
# 2002.0    4
# 2005.0    4
# 2016.0    4
# 1945.0    3
# 1972.0    3
# 2004.0    3
# 2006.0    3
# 2010.0    3
# 2011.0    3
# Name: jmeno, dtype: int64

# %%
metaly[metaly.rok.eq(2003)].head(50)
# Out:
#     stat           vyznamenani                          jmeno     rok  rank  \
# 60    cr  medaile-za-hrdinstvi              Dominique Magnant  2003.0   NaN
# 209   cr    medaile-za-zasluhy  Zuzana Kalabisová - Růžičková  2003.0   2.0
# 275   cr    medaile-za-zasluhy                    Jacek Kuroň  2003.0   2.0
# 189   cr    medaile-za-zasluhy              Lena May Jegerová  2003.0   1.0
# 151   cr    rad-t.-g.-masaryka                  Willy Spühler  2003.0   1.0
# 127   cr  medaile-za-hrdinstvi                Georges Vergoni  2003.0   NaN
# 106   cr    rad-t.-g.-masaryka                    Emil Ludvík  2003.0   3.0
# 138   cr    rad-t.-g.-masaryka               Mary Robinsonová  2003.0   1.0
# 221   cr    medaile-za-zasluhy                   Pavel Klener  2003.0   2.0
# 186   cr    medaile-za-zasluhy                 Lenka Janotová  2003.0   2.0
# 115   cr    rad-t.-g.-masaryka                   Adam Michnik  2003.0   3.0
# 176   cr    medaile-za-zasluhy                Ladislav Chudík  2003.0   1.0
# 87    cr    rad-t.-g.-masaryka       Sergej Adamovič Kovaljov  2003.0   2.0
# 230   cr    medaile-za-zasluhy                     Jiří Kodet  2003.0   1.0
# 61    cr  medaile-za-hrdinstvi               Roman Macharáček  2003.0   NaN
# 93    cr    rad-t.-g.-masaryka                  Miroslav Kusý  2003.0   3.0
# 163   cr    medaile-za-zasluhy                    Martin Huba  2003.0   1.0
# 73    cr  medaile-za-hrdinstvi                 Jaroslav Novák  2003.0   NaN
# 554   cr    medaile-za-zasluhy                 Zdena Tominová  2003.0   1.0
# 107   cr        rad-bileho-lva                    Alois Šiška  2003.0   3.0
# 580   cr    medaile-za-zasluhy            František Vencovský  2003.0   2.0
# 512   cr    medaile-za-zasluhy                 Lászlo Szigeti  2003.0   1.0
# 577   cr    medaile-za-zasluhy               Emília Vášáryová  2003.0   1.0
# 161   cr    rad-t.-g.-masaryka              Jaroslav Škarvada  2003.0   3.0
# 424   cr    medaile-za-zasluhy                      Jan Princ  2003.0   2.0
# 44    cr    medaile-za-zasluhy                   Karel Brožík  2003.0   2.0
# 123   cr    medaile-za-zasluhy               Vlasta Hammerová  2003.0   2.0
# 52    cr    medaile-za-zasluhy            Ramiro Cibrian Uzal  2003.0   3.0
# 46    cr        rad-bileho-lva               Alexander Dubček  2003.0   1.0
# 474   cr    medaile-za-zasluhy                  Václav Snítil  2003.0   2.0
# 5     cr    medaile-za-zasluhy             Timothy Garton Ash  2003.0   1.0
# 49    cr    medaile-za-zasluhy                   Erhard Busek  2003.0   2.0
# 519   cr    medaile-za-zasluhy                    Ivan Šetlík  2003.0   2.0
# 298   cr    medaile-za-zasluhy                 Ľubomír Lipták  2003.0   1.0
# 56    cr        rad-bileho-lva                    Árpád Göncz  2003.0   1.0
# 9     cr    rad-t.-g.-masaryka                Elena Bonnerová  2003.0   2.0
# 292   cr    medaile-za-zasluhy                  Josef Liesler  2003.0   2.0
# 2     cr    rad-t.-g.-masaryka                 Luisa Abrahams  2003.0   3.0
# 50    cr    rad-t.-g.-masaryka                   Václav Havel  2003.0   1.0
# 178   cr    rad-t.-g.-masaryka               Antje Vollmerová  2003.0   3.0
# 83    cr    medaile-za-zasluhy                  Peter Dvorský  2003.0   1.0
# 627   cr    medaile-za-zasluhy                     Petr Zeman  2003.0   2.0
# 623   cr    medaile-za-zasluhy                 Dana Zátopková  2003.0   2.0
# 461   cr    medaile-za-zasluhy            Vratislav Schreiber  2003.0   2.0
# 11    cr    medaile-za-zasluhy               Wolfgang Bandion  2003.0   1.0
# 453   cr    medaile-za-zasluhy                Július Satinský  2003.0   1.0
# 613   cr    medaile-za-zasluhy                 Herbert Werner  2003.0   2.0
# 486   cr    medaile-za-zasluhy               František Stárek  2003.0   2.0
# 286   cr    medaile-za-zasluhy                   Milan Lasica  2003.0   1.0
# 89    cr        rad-bileho-lva                   Anton Petrák  2003.0   1.0
#
#      retez   skupina  inmemoriam pohlavi prezident
# 60   False       NaN       False     muz     Klaus
# 209  False       NaN       False    zena     Klaus
# 275  False       NaN       False     muz     Klaus
# 189  False       NaN       False    zena     Klaus
# 151  False       nan        True     muz     Klaus
# 127  False       NaN        True     muz     Klaus
# 106  False       nan       False     muz     Klaus
# 138  False       nan       False    zena     Klaus
# 221  False       NaN       False     muz     Klaus
# 186  False       NaN       False    zena     Klaus
# 115  False       nan       False     muz     Klaus
# 176  False       NaN       False     muz     Klaus
# 87   False       nan       False     muz     Klaus
# 230  False       NaN       False     muz     Klaus
# 61   False       NaN       False     muz     Klaus
# 93   False       nan       False     muz     Klaus
# 163  False       NaN       False     muz     Klaus
# 73   False       NaN       False     muz     Klaus
# 554  False       NaN       False    zena     Klaus
# 107  False  vojenská        True     muz     Klaus
# 580  False       NaN       False     muz     Klaus
# 512  False       NaN       False     muz     Klaus
# 577  False       NaN       False    zena     Klaus
# 161  False       nan       False     muz     Klaus
# 424  False       NaN       False     muz     Klaus
# 44   False       NaN       False     muz     Klaus
# 123  False       NaN       False    zena     Klaus
# 52   False       NaN       False     muz     Klaus
# 46   False  občanská        True     muz     Klaus
# 474  False       NaN       False     muz     Klaus
# 5    False       NaN       False     muz     Klaus
# 49   False       NaN       False     muz     Klaus
# 519  False       NaN       False     muz     Klaus
# 298  False       NaN       False     muz     Klaus
# 56   False  občanská       False     muz     Klaus
# 9    False       nan       False    zena     Klaus
# 292  False       NaN       False     muz     Klaus
# 2    False       nan       False    zena     Klaus
# 50   False       nan       False     muz     Klaus
# 178  False       nan       False    zena     Klaus
# 83   False       NaN       False     muz     Klaus
# 627  False       NaN       False     muz     Klaus
# 623  False       NaN       False    zena     Klaus
# 461  False       NaN       False     muz     Klaus
# 11   False       NaN       False     muz     Klaus
# 453  False       NaN        True     muz     Klaus
# 613  False       NaN       False     muz     Klaus
# 486  False       NaN       False     muz     Klaus
# 286  False       NaN       False     muz     Klaus
# 89   False  vojenská       False     muz     Klaus

# %%
metaly[metaly.rok.isin([2004,2005,2006,2007,2008,2009,2010,2011,2012])].groupby("rok")["jmeno"].nunique().mean()
# Out:
# 23.22222222222222

# %%
metaly[(metaly["prezident"] == "Zeman") & (metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["rank"] != 1)]
# Out:
#     stat         vyznamenani                      jmeno     rok  rank  retez  \
# 100   cr  rad-t.-g.-masaryka           Detlef Lingemann  2014.0   3.0  False
# 94    cr  rad-t.-g.-masaryka           Michaela Küchler  2014.0   4.0  False
# 96    cr  rad-t.-g.-masaryka           Adam Kwiatkowský  2016.0   3.0  False
# 76    cr  rad-t.-g.-masaryka                  Jan Kačer  2016.0   4.0  False
# 48    cr      rad-bileho-lva   Dominik kardinál Duka OP  2016.0   3.0  False
# 110   cr      rad-bileho-lva  Ferdinand Trauttmansdorff  2016.0   4.0  False
# 23    cr  rad-t.-g.-masaryka               Andrzej Dero  2016.0   3.0  False
# 75    cr  rad-t.-g.-masaryka    Katarzyna Kacperczyková  2016.0   4.0  False
#
#       skupina  inmemoriam pohlavi prezident
# 100       nan       False     muz     Zeman
# 94        nan       False    zena     Zeman
# 96        nan       False     muz     Zeman
# 76        nan       False     muz     Zeman
# 48   občanská       False     muz     Zeman
# 110  občanská       False     muz     Zeman
# 23        nan       False     muz     Zeman
# 75        nan       False    zena     Zeman

# %%
metaly[(metaly["vyznamenani"] == "rad-bileho-lva") & (metaly["prezident"] == "Klaus") & (metaly["inmemoriam"] == True)]
# Out:
#     stat     vyznamenani                      jmeno     rok  rank  retez  \
# 107   cr  rad-bileho-lva                Alois Šiška  2003.0   3.0  False
# 46    cr  rad-bileho-lva           Alexander Dubček  2003.0   1.0  False
# 73    cr  rad-bileho-lva       Rudolf Severin Krzák  2004.0   3.0  False
# 40    cr  rad-bileho-lva               Josef Buršík  2005.0   1.0  False
# 39    cr  rad-bileho-lva                Josef Bryks  2006.0   2.0  False
# 63    cr  rad-bileho-lva              Rudolf Hrubec  2007.0   1.0  False
# 42    cr  rad-bileho-lva               Otakar Černý  2009.0   1.0  False
# 23    cr  rad-bileho-lva  Lech Aleksander Kaczyński  2010.0   1.0   True
#
#       skupina  inmemoriam pohlavi prezident
# 107  vojenská        True     muz     Klaus
# 46   občanská        True     muz     Klaus
# 73   vojenská        True     muz     Klaus
# 40   vojenská        True     muz     Klaus
# 39   vojenská        True     muz     Klaus
# 63   vojenská        True     muz     Klaus
# 42   vojenská        True     muz     Klaus
# 23   občanská        True     muz     Klaus

# %%
metaly[metaly.jmeno.str.contains("Weit")]
# Out:
# Empty DataFrame
# Columns: [stat, vyznamenani, jmeno, rok, rank, retez, skupina, inmemoriam, pohlavi, prezident]
# Index: []

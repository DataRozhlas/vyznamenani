# %% [markdown]
# # Státní vyznamenání: explorace dat
#
# ### Elevator pitch (stále nekompletní)
#
# Víme, jak vyznamenávali jednotliví čeští prezidenti! Možná i líp než oni sami.
#
# ## Osnova
#
# ### teaser-anketa
#
# - Zeman naposled
# - na koho se zapomnělo?
# - zajímavej způsob, jak vybrat významné lidi: Notable People
# - metodologie
# - žebříček českých (tabulka)
# - žebříček nevyznamenaných - hlasování
# - vybírat nemůžete, můžete jim doplnit profily na wiki
#
# ### úvod
#
# - třetí prezident uzavírá svůj druhý mandát, čas bilancovat!
# - máme tyto 2 řády a tyto 2 medaile, za co
#
# ### stať
#
# - kdo jich rozdal kolik a jakých stupňů, kdo vyznamenával ženy, kdo mrtvé
#     - Havel toho rozdával nejvíc, a to i na konci mandátu, kdy už uplynulo 13 let od revoluce a 10 od vyhlášení ČR (což asi byly důvody proto to házet z vrtulníku).
#     - Klaus šetřil prvními stupni a třídami, Zeman dává skoro jenom je.
#     - Klaus taky málo vyznamenával nebožtíky.
#     - Havel nevyznamenal moc žen, Klaus to trochu zlepšil, Zeman se držel, ale v druhém termínu to zas padá.
# - kdo z vyznamenaných byl "povýšen"
#     - Jenom Zeman znovuvyznamenává nositele státních vyznamenání ČR.
#
# ### touch of divno
#
# - vědci v Nature publikovali článek o tom, jak spočítat něčí významnost + rovnou publikovali dataset s 2 000 000 nejvýznamějších lidí historie (k roku 2019)
# - takto vypadá prolnutí seznamu vyznamenaných Řádem Bílého Lva a významných lidí
#     - velkej večírek byl v roce 1999, Havel vyznamenal globální elitu
#
# ### závěr
#
# - na které významné české (nebo i světové?) osobnosti by se mohl zaměřit příští prezident?
#
#
# ### Zbývá
#
# Sběr:
# - rozdělit 1 jméno do 2
# - Jindřich Macháček: narození a úmrtí. v knihovně: https://dnnt.mzk.cz/periodical/uuid:b56c15a0-acbf-11e7-91d5-005056825209?fulltext=%22Jind%C5%99ich%20Mach%C3%A1%C4%8Dek%22%20gener%C3%A1lmajor%20 nebo https://dnnt.mzk.cz/view/uuid:2891f1a0-a29b-11e2-9a9f-005056827e51?page=uuid:e002b1be-4335-45db-8444-321a3e156d5e&fulltext=%22mach%C3%A1%C4%8Dek%20jind%C5%99ich%22
# - zaměřit se na první republiku
# - fakin kontrola
# - našinci x cizinci
#
# Analýza:
# - multiples/skokani
#
# Co nejjednodušší analýza archiválií:
# - kolik vyznamenání ročně se dávalo za ČSR a ČSSR
#
# Porovnání se zahraničím?
# - Slovensko?
#
#
# ### Výpisky
#
# - Řád Bílého lva je nejvyšší státní vyznamenání České republiky. Původně byl udělován osobám, které se zvlášť vynikajícím způsobem zasloužily o Československo, a to od roku 1922. V letech 1922–1990 se tento řád oficiálně nazýval „Československý řád Bílého lva“.
#     - _Řád Bílého lva propůjčuje nebo uděluje prezident republiky a) občanům České republiky za zvláště vynikající zásluhy o stát, zejména v oblasti politiky, správy státu, rozvoje hospodářství, vědy, techniky, kultury, umění, školství, za mimořádné zásluhy o obranu a bezpečnost státu, za vynikající velitelskou a bojovou činnost, za vědeckou a odbornou práci vojenského a branného charakteru a za významné proslavení vlasti v zahraničí, b) těm, kteří nejsou občany České republiky, za zvláště vynikající zásluhy ve prospěch České republiky._
#     - S řádovým řetězem se vyznamenání uděluje pouze hlavám států.
#     - Českým státním občanům se řád neuděluje, ale propůjčuje.
#
# - Řád Tomáše Garrigua Masaryka je vyšším státním vyznamenáním České republiky a bývalého Československa. Prezident republiky je uděluje nebo propůjčuje osobám, které se vynikajícím způsobem zasloužily o rozvoj demokracie, humanity a lidských práv. Řád vznikl v roce 1990 jako vyznamenání určené pouze pro československé občany; po rozpadu federace byl obnoven roku 1994.
#     - _Řád Tomáše Garrigua Masaryka (dále jen "Řád T.G.M.") propůjčuje nebo uděluje prezident republiky osobám, které se vynikajícím způsobem zasloužily o rozvoj demokracie, humanity a lidská práva._
#
# - Medaile Za hrdinství je nižší státní vyznamenání České republiky.
#     - _Medaili Za hrdinství uděluje prezident republiky osobám za hrdinství v boji a těm, kteří se s nasazením vlastního života zasloužili o záchranu lidského života nebo značných materiálních hodnot._
#
# - Medaile Za zásluhy je nižší státní vyznamenání České republiky.
#     - Vznikla v roce 1990. Medaili Za zásluhy uděluje prezident republiky osobám, které se zasloužily o stát nebo územní samosprávný celek v oblasti hospodářské, vědy, techniky, kultury, umění, sportu, výchovy a školství, obrany, bezpečnosti státu a občanů. Dělí se do tří stupňů, kterým odpovídá materiál a počet fialových pruhů na stužce.[1] I. stupeň medaile je nejvyšší, je ražen ze stříbra a pozlacen, II. stupeň je ražen ze stříbra a III. stupeň je ražen z bronzu. Výtvarným autorem medaile je Jiří Harcuba.
#        - _Medaili Za zásluhy uděluje prezident republiky osobám, které se zasloužily o stát nebo územní samosprávný celek v oblasti hospodářské, vědy, techniky, kultury, umění, sportu, výchovy a školství, obrany, bezpečnosti státu a občanů._
#
# - Medaile Za hrdinství je nižší státní vyznamenání České republiky. Je udělováno jako vyznamenání osob za hrdinství v boji a vyznamenání těch osob, které se s nasazením vlastního života zasloužily o záchranu lidského života nebo značných materiálních hodnot.
#
# - Prezident České a Slovenské federativní republiky, jenž byl zároveň i automatickým nositelem řádové insignie I. třídy Řádu Milana Rastislava Štefánika (dále jen Řád M. R. Štefánika) měl pravomoc - propůjčit řád navrhovaným osobnostem. Vrácení prezidentovy insignie (I. třídy řádu) nastalo jen v případě neprodloužení lhůty o propůjčení řádu i po dobu skončení prezidentské funkce prostřednictvím usnesení Federálního shromáždění. Vyznamenávání osob prezidentem ČSFR příslušným řádem se konalo vždy 8. 5. Tento den byl považován za řádový den se symbolikou ukončení druhé světové války v Evropě.132 Zákon nepovoloval propůjčení řádu v jiný den než v řádový den.
#
# ***
#
# Slavnostní ceremoniál se konal již tradičně 28. října 1992 ve Vladislavském sále na Pražském hradě. Řád Tomáše Garriguea Masaryka (dále jen T. G. Masaryka) byl propůjčen 64 osobnostem ve IV. stupni. Zákonní navrhovatelé115 se dohodli o tom, že v tomto roce vyznamenání T. G Masaryka propůjčí pouze nežijícím osobnostem in memoriam. 116 V takovém případě získávali pozůstalí vyznamenaného pouze listinu o propůjčení vyznamenání, nikoli řádovou insignii vyznamenání.117
#
# Další změnou oproti předchozímu předávání řádu (v roce 1991), prezident České a Slovenské federativní republiky (dále jen ČSFR) - Václav Havel rezignoval tehdy na svůj post, a tak předávání se ujal (dle zákonné pravomoci) předseda vlády ČSFR, Jan Stráský.118
#
# Televizní záznam předávání státního vyznamenání T. G. Masaryka nebyl nikdy odvysílán. Z celkového audiovizuálního materiálu se použily jen krátké sestřihy do denního Zpravodajství a Deníku ČTV. O úvod a komentář záznamu se postaral Ladislav Špaček, tehdy jako šéfredaktor domácího zpravodajství ČT (v roce 1990).121
#
# ***
#
# Řád Bílého lva slaví sto let od vzniku. Původně však nebyl pro Čechy
# Zdroj: https://www.idnes.cz/zpravy/domaci/rad-bileho-lva-oceneni-sto-let-vznik-prezident-vladislavsky-sal.A221002_181046_domaci_albe
#
# ### Z datasetu Notable people:
#
# Kdo chybí z největších Čechů? (Medián lvů in memoriam: 35 let po smrti, rekord 88. Jako filtr nastaveno to druhé.)
# - Kurt_Gödel	mathematician	1978.0
# - Ivana_Trump	author	NaN
# - TGM 1937.0
# - Alphonse_Mucha	artist	1939.0
# - Ivan_Lendl	player	NaN
# - Tomáš_Rosický	football	NaN
# - Tomáš_Berdych	player	NaN
# - Miloš_Zeman	politician	NaN
# - Richard_von_Coudenhove-Kalergi	politician	1972.0
# - Edvard_Beneš	politician	1948.0
# - Tom_Stoppard	playwright	NaN
# - Karolína_Plíšková	player	NaN
# - Jozef_Tiso	politician	1947.0
# - Karolína_Kurková	model	NaN
# - Silvia_Saint	actor	NaN
# - Max_Brod	author	1968.0
# - Jan_Koller	football	NaN
# - Ivan_Reitman	film	NaN
#
# ### Otázky, na které neodpoví data – zeptat se lidí:
#
# - Proč se nevyznamenávalo 1993 a 1994?
# - Proč Zeman dává jen první třídy a stupně?
# - Podle čeho se rozhodovalo, komu po rozdělení federace dát metál znovu?
#
# ### Nepřesnosti na webu:
#
# Alfred Duff Cooper není in memoriam! Lech Aleksander Kaczyński taky ne! Patton dtto. Wtf. Vranitzky počeštěný.
#
# who the fuck is Aleš Weiter

# %% [markdown]
# ## Připrav se, hrajem

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cr_lev = pd.read_json("cr-rad-bileho-lva.json")
cr_masaryk = pd.read_json("cr-rad-t.-g.-masaryka.json")
cr_zasluhy = pd.read_json("cr-medaile-za-zasluhy.json")
cr_hrdinstvi = pd.read_json("cr-medaile-za-hrdinstvi.json")
csfr_lev = pd.read_json("csfr-rad-bileho-lva.json")
csfr_masaryk = pd.read_json("csfr-rad-t.-g.-masaryka.json")
csfr_stefanik = pd.read_json("csfr-rad-m.-r.-stefanika.json")
csfr_zasluhy = pd.read_json("csfr-medaile-za-zasluhy.json")
csfr_hrdinstvi = pd.read_json("csfr-medaile-za-hrdinstvi.json")

# %%
Havel = [1990, 1991, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002]
Klaus = [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]
Zeman = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
Strasky = [1992]

# %%
metaly = pd.concat([cr_lev, cr_masaryk, cr_zasluhy, cr_hrdinstvi, csfr_lev, csfr_masaryk, csfr_stefanik, csfr_hrdinstvi, csfr_zasluhy], axis=0, join='outer')

# %%
with open("zenskajmena.txt", 'r', encoding="utf-8") as zenskajmena:
    zenskajmena = zenskajmena.read().splitlines()
    zeny = []
    for line in zenskajmena:
        zeny.append(line + " ")

# %%
metaly.loc[metaly.jmeno.eq("Petra Kellner"),"jmeno"]="Petr Kellner"
metaly.loc[metaly.jmeno.eq("Hana"),"jmeno"]="Hana Hegerová"

metaly.loc[metaly.jmeno.eq("Hanuš"),"jmeno"]="Hanuš Holzer"
metaly.loc[metaly.jmeno.eq("Kare"),"jmeno"]="Karel Kryl"
metaly.loc[metaly.jmeno.eq("Karel"),"jmeno"]="Karel Hanzl"
metaly.loc[metaly.jmeno.eq("František"),"jmeno"]="František Kriegel"
metaly.loc[metaly.jmeno.eq("Detlef"),"jmeno"]="Detlef Lingemann"

metaly.loc[metaly.jmeno.eq("Alfred Duff Cooper"),"inmemoriam"]=True
metaly.loc[metaly.jmeno.eq("Josef Robotka"),"inmemoriam"]=True
metaly.loc[metaly.jmeno.eq("Lech Aleksander Kaczyński"),"inmemoriam"]=True
metaly.loc[metaly.jmeno.eq("George S. Patton"),"inmemoriam"]=True

# %%
metaly = metaly[metaly["jmeno"] != "Aleš Weiter"]

# %%
metaly.loc[(metaly["jmeno"] == "Karel Raška") & (metaly["rok"] == 2021),"jmeno"]="Karel Raška II."
metaly.loc[(metaly["jmeno"] == "Pavel Žák") & (metaly["rok"] == 2021),"jmeno"]="Pavel Žák II."
metaly.loc[(metaly["jmeno"] == "Jan Procházka") & (metaly["rok"] == 2017),"jmeno"]="Jan Procházka II."
metaly.loc[(metaly["jmeno"] == "Jaroslav Strnad") & (metaly["rok"] == 2018),"jmeno"]="Jaroslav Strnad II."
metaly.loc[(metaly["jmeno"] == "Jan Novák") & (metaly["inmemoriam"] == True),"jmeno"]="Jan Novák II."

# %%
metaly["pohlavi"] = "muz"
metaly.loc[metaly.jmeno.str.contains('|'.join(zeny)),"pohlavi"]="zena"

# %%
metaly = metaly[metaly["rok"].notnull()]
metaly = metaly[metaly["jmeno"].notnull()]
metaly = metaly.sort_values(by="rok")

# %%
metaly.loc[metaly.rok.isin(Havel),"prezident"]="Havel"
metaly.loc[metaly.rok.isin(Klaus),"prezident"]="Klaus"
metaly.loc[metaly.rok.isin(Zeman),"prezident"]="Zeman"
metaly.loc[metaly.rok.isin(Strasky),"prezident"]="Stráský"

# %%
metaly = metaly.sort_values(by=["rok","vyznamenani","jmeno"])

# %%
metaly = metaly.reset_index()

# %%
metaly["id"] = metaly.index

# %% [markdown]
# ## Kontrola

# %%
metaly.groupby("vyznamenani")["jmeno"].nunique()
# Out:
# vyznamenani
# medaile-za-hrdinstvi    138
# medaile-za-zasluhy      792
# rad-bileho-lva          123
# rad-m.-r.-stefanika      84
# rad-t.-g.-masaryka      353
# Name: jmeno, dtype: int64

# %%
metaly.groupby("vyznamenani")["index"].nunique()
# Out:
# vyznamenani
# medaile-za-hrdinstvi    137
# medaile-za-zasluhy      637
# rad-bileho-lva          120
# rad-m.-r.-stefanika      84
# rad-t.-g.-masaryka      188
# Name: index, dtype: int64

# %%
metaly.groupby("vyznamenani")["id"].nunique()
# Out:
# vyznamenani
# medaile-za-hrdinstvi    138
# medaile-za-zasluhy      798
# rad-bileho-lva          125
# rad-m.-r.-stefanika      84
# rad-t.-g.-masaryka      354
# Name: id, dtype: int64

# %%
metaly.sample(10)
# Out:
#       index  stat           vyznamenani                   jmeno     rok  rank  \
# 1038    148    cr    rad-t.-g.-masaryka          Karel Skalický  2006.0   4.0
# 788     131    cr  medaile-za-hrdinstvi  Albína Wiesenbergerová  2001.0   NaN
# 753     174    cr    medaile-za-zasluhy            Eiichi Chino  2000.0   1.0
# 230      19  csfr    medaile-za-zasluhy                Ján Valo  1992.0   1.0
# 1258    431    cr    medaile-za-zasluhy     František Radkovský  2015.0   1.0
# 110       6  csfr    rad-t.-g.-masaryka    Josef kardinál Beran  1991.0   1.0
# 469     182    cr    rad-t.-g.-masaryka             René Wellek  1995.0   1.0
# 711     112    cr    rad-t.-g.-masaryka          Zdena Mašínová  1998.0   4.0
# 994      73    cr        rad-bileho-lva    Rudolf Severin Krzák  2004.0   3.0
# 754     347    cr    medaile-za-zasluhy            Ivan Moravec  2000.0   1.0
#
#       retez   skupina  inmemoriam pohlavi prezident    id
# 1038  False       nan       False     muz     Klaus  1038
# 788   False       NaN       False    zena     Havel   788
# 753   False       NaN       False     muz     Havel   753
# 230     NaN       NaN       False     muz   Stráský   230
# 1258  False       NaN       False     muz     Zeman  1258
# 110   False       NaN        True     muz     Havel   110
# 469   False       nan       False     muz     Havel   469
# 711   False       nan        True    zena     Havel   711
# 994   False  vojenská        True     muz     Klaus   994
# 754   False       NaN       False     muz     Havel   754

# %% [markdown]
# ## Kolik celkem

# %%
metaly[metaly["stat"] == "cr"].groupby("jmeno").nunique()
# Out:
#                              index  stat  vyznamenani  rok  rank  retez  \
# jmeno
# Abdullah II. bin Al Hussein      1     1            1    1     1      1
# Adam Kwiatkowský                 1     1            1    1     1      1
# Adam Michnik                     1     1            1    1     1      1
# Adolf Born                       1     1            1    1     1      1
# Adolf Müller                     1     1            1    1     1      1
# ...                            ...   ...          ...  ...   ...    ...
# Ľubomír Lipták                   1     1            1    1     1      1
# Šimon Pánek                      1     1            1    1     1      1
# Štefan Margita                   1     1            1    1     1      1
# Štěpán Dohodil                   1     1            1    1     0      1
# Štěpán Popovič                   1     1            1    1     1      1
#
#                              skupina  inmemoriam  pohlavi  prezident  id
# jmeno
# Abdullah II. bin Al Hussein        1           1        1          1   1
# Adam Kwiatkowský                   1           1        1          1   1
# Adam Michnik                       1           1        1          1   1
# Adolf Born                         0           1        1          1   1
# Adolf Müller                       0           1        1          1   1
# ...                              ...         ...      ...        ...  ..
# Ľubomír Lipták                     0           1        1          1   1
# Šimon Pánek                        0           1        1          1   1
# Štefan Margita                     0           1        1          1   1
# Štěpán Dohodil                     0           1        1          1   1
# Štěpán Popovič                     0           1        1          1   1
#
# [1068 rows x 11 columns]

# %% [markdown]
# ## Hledání trendů a rozdílů mezi prezidenty

# %%
lvi_pocet = pd.Series(metaly[metaly["vyznamenani"] == "rad-bileho-lva"].groupby("rok")["id"].nunique())
masaryk_pocet = pd.Series(metaly[metaly["vyznamenani"] == "rad-t.-g.-masaryka"].groupby("rok")["id"].nunique())
stefanik_pocet = pd.Series(metaly[metaly["vyznamenani"] == "rad-m.-r.-stefanika"].groupby("rok")["id"].nunique())
zasluhy_pocet = pd.Series(metaly[metaly["vyznamenani"] == "medaile-za-zasluhy"].groupby("rok")["id"].nunique())
hrdinstvi_pocet = pd.Series(metaly[metaly["vyznamenani"] == "medaile-za-hrdinstvi"].groupby("rok")["id"].nunique())

# %%
roky = metaly["rok"].sort_values().drop_duplicates().to_list()

# %%
metaly_grouped_vyz = pd.DataFrame((metaly.groupby(["rok", "vyznamenani"])["id"].nunique()).unstack())

# %%
metaly_grouped_vyz.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly_grouped_rank = pd.DataFrame((metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi")].groupby(["rok", "rank"])["id"].nunique()).unstack())

# %%
metaly_grouped_rank.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %% [markdown]
# ⬆️GRAF1: Je podstatý tím, že:
#
# 1. Zachycuje porevoluční bonanzu,
#
# 2. zachycuje Havlovy medaile na konci funkčních období,
#
# 3. viditelně ukazuje propad 1. tříd a počtu vyznamenání obecně za Klause,
#
# 4. zachycuje Zemanovu inflaci 1. tříd.
#
# Nejsou tam vidět Medaile za hrdinství, které jediné nemají skupiny/třídy. Nevím, zda je tam cpát. Jsou do jistý míry ovlivněný tím, jestli ten rok zrovna někde v AFG nepadli vojáci.

# %%
pd.DataFrame((metaly.groupby(["rok", "vyznamenani"])["id"].nunique()).unstack()).plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[(metaly["stat"] == "cr")].groupby("prezident")["id"].nunique()
# Out:
# prezident
# Havel    500
# Klaus    267
# Zeman    313
# Name: id, dtype: int64

# %%
metaly[(metaly["stat"] == "cr")].groupby("prezident")["id"].nunique() / metaly[(metaly["stat"] == "cr")].groupby("prezident")["rok"].nunique()
# Out:
# prezident
# Havel    62.500000
# Klaus    26.700000
# Zeman    34.777778
# dtype: float64

# %%
34.777778 / 26.600000
# Out:
# 1.3074352631578945

# %%
metaly.groupby("rok")["id"].nunique()
# Out:
# rok
# 1990.0      4
# 1991.0    153
# 1992.0    262
# 1995.0     54
# 1996.0     65
# 1997.0     69
# 1998.0    105
# 1999.0     35
# 2000.0     41
# 2001.0     46
# 2002.0     85
# 2003.0     58
# 2004.0     22
# 2005.0     23
# 2006.0     22
# 2007.0     24
# 2008.0     28
# 2009.0     24
# 2010.0     23
# 2011.0     21
# 2012.0     22
# 2013.0     30
# 2014.0     34
# 2015.0     35
# 2016.0     31
# 2017.0     43
# 2018.0     41
# 2019.0     42
# 2020.0     30
# 2021.0     27
# Name: id, dtype: int64

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["stat"] == "cr") & (metaly["inmemoriam"] == True)].groupby("rok")["id"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["inmemoriam"] == True)].groupby("prezident")["id"].nunique() / metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi")].groupby("prezident")["id"].nunique()
# Out:
# prezident
# Havel      0.319788
# Klaus      0.078740
# Stráský    0.340996
# Zeman      0.189286
# Name: id, dtype: float64

# %%
metaly[(metaly["vyznamenani"] == "medaile-za-zasluhy") & (metaly["stat"] == "cr") & (metaly["inmemoriam"] == False)].groupby("rok")["id"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["stat"] == "cr")].groupby("rok")["id"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[(metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["stat"] == "cr")].groupby("prezident")["id"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='prezident'>

# %% [markdown]
# ## Rozdíly mezi metály

# %%
metaly[metaly["stat"] == "cr"].groupby(["vyznamenani","inmemoriam"])["id"].nunique()
# Out:
# vyznamenani           inmemoriam
# medaile-za-hrdinstvi  False          95
#                       True           42
# medaile-za-zasluhy    False         563
#                       True           73
# rad-bileho-lva        False          74
#                       True           46
# rad-t.-g.-masaryka    False         136
#                       True           51
# Name: id, dtype: int64

# %%
metaly_neboztici = metaly[(metaly["inmemoriam"] == True) & (metaly["stat"] == "cr")].groupby(["vyznamenani"])["id"].nunique() / metaly[metaly["stat"] == "cr"].groupby(["vyznamenani"])["id"].nunique()

# %%
metaly_neboztici
# Out:
# vyznamenani
# medaile-za-hrdinstvi    0.306569
# medaile-za-zasluhy      0.114780
# rad-bileho-lva          0.383333
# rad-t.-g.-masaryka      0.272727
# Name: id, dtype: float64

# %% [markdown]
# ## Není ženské otázky - je otázka lidská (TGM)

# %%
gender = metaly[(metaly["pohlavi"] == "zena")].groupby("rok")["id"].nunique() / metaly.groupby("rok")["id"].nunique()

# %%
gender.plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
pd.DataFrame(metaly[(metaly["stat"] == "cr") & (metaly["pohlavi"] == "zena")].groupby("prezident")["id"].nunique() / metaly[(metaly["stat"] == "cr")].groupby("prezident")["id"].nunique())
# Out:
#                  id
# prezident
# Havel      0.120000
# Klaus      0.168539
# Zeman      0.159744

# %%
pd.DataFrame(metaly[(metaly["stat"] == "cr") & (metaly["pohlavi"] == "zena")].groupby("vyznamenani")["id"].nunique() / metaly[(metaly["stat"] == "cr")].groupby("vyznamenani")["id"].nunique())
# Out:
#                             id
# vyznamenani
# medaile-za-hrdinstvi  0.072993
# medaile-za-zasluhy    0.180818
# rad-bileho-lva        0.041667
# rad-t.-g.-masaryka    0.133690

# %% [markdown]
# ## Vícenásobně vyznamenaní

# %%
vicenasobni_a = pd.DataFrame(metaly.groupby("jmeno")["vyznamenani"].nunique().nlargest(45))
vicenasobni_a = vicenasobni_a[vicenasobni_a["vyznamenani"] > 1]
vicenasobni_a
# Out:
#                      vyznamenani
# jmeno
# Alois Šiška                    2
# Erazim Kohák                   2
# František Fajtl                2
# Hana Hegerová                  2
# Jan Kačer                      2
# Jan Šrámek                     2
# Jiřina Bohdalová               2
# Jiří Kolář                     2
# Jiří Suchý                     2
# Josef Buršík                   2
# Josef Bílý                     2
# Josef Veselý                   2
# Josef Štemberka                2
# Karel Gott                     2
# Karel Kryl                     2
# Karel Kutlvašr                 2
# Karel Kuttelwascher            2
# Karel Pezl                     2
# Radovan Procházka              2
# Rudolf Pernický                2
# Stanislav Hlučka               2
# Tomáš Sedláček                 2
# Václav Havel                   2

# %%
vicenasobni = pd.DataFrame(metaly.groupby("jmeno")["rok"].nunique().nlargest(45))
vicenasobni = vicenasobni[vicenasobni["rok"] > 1]

poprve = pd.Series(metaly.groupby("jmeno")["rok"].first(), name="poprve")
prvni_prezident = pd.Series(metaly.groupby("jmeno")["prezident"].first(), name="prvni_prezident")
podruhe = pd.Series(metaly.groupby("jmeno")["rok"].last(), name="podruhe")
druhy_prezident = pd.Series(metaly.groupby("jmeno")["prezident"].last(), name="druhy_prezident")
prvni_metal = pd.Series(metaly.groupby("jmeno")["vyznamenani"].first(), name="prvni_metal")
druhy_metal = pd.Series(metaly.groupby("jmeno")["vyznamenani"].last(), name="druhy_metal")
prvni_rank = pd.Series(metaly.groupby("jmeno")["rank"].first(), name="prvni_rank")
druhy_rank = pd.Series(metaly.groupby("jmeno")["rank"].last(), name="druhy_rank")

vicenasobni = vicenasobni.merge(poprve, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(podruhe, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(prvni_prezident, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(druhy_prezident, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(prvni_metal, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(druhy_metal, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(prvni_rank, on="jmeno", how="left")
vicenasobni = vicenasobni.merge(druhy_rank, on="jmeno", how="left")

vicenasobni["rozestup"] = vicenasobni["podruhe"] - vicenasobni["poprve"]

vicenasobni.sort_values(by="rozestup")
# Out:
#                      rok  poprve  podruhe prvni_prezident druhy_prezident  \
# jmeno
# Josef Sedláček         2  1992.0   1996.0         Stráský           Havel
# Viktor Fischl          2  1991.0   1996.0           Havel           Havel
# Radovan Procházka      2  1992.0   1997.0         Stráský           Havel
# Josef Suk              2  1992.0   1999.0         Stráský           Havel
# Jiřina Bohdalová       2  2013.0   2021.0           Zeman           Zeman
# Emil Boček             2  2010.0   2019.0           Klaus           Zeman
# Jaromír Jágr           2  2010.0   2019.0           Klaus           Zeman
# Francois Mitterrand    2  1990.0   1999.0           Havel           Havel
# Jiří Kolář             2  1991.0   2002.0           Havel           Havel
# Karel Gott             2  2009.0   2020.0           Klaus           Zeman
# Alois Šiška            2  1991.0   2003.0           Havel           Klaus
# Hana Hegerová          2  2002.0   2014.0           Havel           Zeman
# Marie Svatošová        2  2002.0   2015.0           Havel           Zeman
# Tomáš Sedláček         2  1991.0   2004.0           Havel           Klaus
# František Fajtl        2  1991.0   2004.0           Havel           Klaus
# Josef Buršík           2  1991.0   2005.0           Havel           Klaus
# Rudolf Pernický        2  1991.0   2005.0           Havel           Klaus
# Stanislav Hlučka       2  1991.0   2005.0           Havel           Klaus
# Erazim Kohák           2  1998.0   2013.0           Havel           Zeman
# Jan Šrámek             2  1991.0   2007.0           Havel           Klaus
# Josef Váňa             2  1992.0   2009.0         Stráský           Klaus
# Josef Veselý           2  1991.0   2009.0           Havel           Klaus
# Jiří Suchý             2  1995.0   2013.0           Havel           Zeman
# Karel Kuttelwascher    2  1998.0   2016.0           Havel           Zeman
# Jan Kačer              2  1998.0   2016.0           Havel           Zeman
# Karel Kryl             2  1995.0   2014.0           Havel           Zeman
# Josef Štemberka        2  1992.0   2014.0         Stráský           Zeman
# Juraj Kukura           2  1992.0   2017.0         Stráský           Zeman
# Karel Kutlvašr         2  1992.0   2017.0         Stráský           Zeman
# Karel Pezl             2  1992.0   2017.0         Stráský           Zeman
# Josef Bílý             2  1992.0   2018.0         Stráský           Zeman
#
#                               prvni_metal         druhy_metal  prvni_rank  \
# jmeno
# Josef Sedláček         medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Viktor Fischl          rad-t.-g.-masaryka  rad-t.-g.-masaryka         3.0
# Radovan Procházka      medaile-za-zasluhy      rad-bileho-lva         1.0
# Josef Suk              medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Jiřina Bohdalová       medaile-za-zasluhy      rad-bileho-lva         1.0
# Emil Boček                 rad-bileho-lva      rad-bileho-lva         3.0
# Jaromír Jágr           medaile-za-zasluhy  medaile-za-zasluhy         2.0
# Francois Mitterrand        rad-bileho-lva      rad-bileho-lva         1.0
# Jiří Kolář             rad-t.-g.-masaryka  medaile-za-zasluhy         2.0
# Karel Gott             medaile-za-zasluhy      rad-bileho-lva         1.0
# Alois Šiška           rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Hana Hegerová          medaile-za-zasluhy  rad-t.-g.-masaryka         3.0
# Marie Svatošová        medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Tomáš Sedláček        rad-m.-r.-stefanika  rad-t.-g.-masaryka         3.0
# František Fajtl       rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Josef Buršík          rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Rudolf Pernický       rad-m.-r.-stefanika      rad-bileho-lva         3.0
# Stanislav Hlučka      rad-m.-r.-stefanika  rad-t.-g.-masaryka         3.0
# Erazim Kohák           medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Jan Šrámek             rad-t.-g.-masaryka  medaile-za-zasluhy         2.0
# Josef Váňa             medaile-za-zasluhy  medaile-za-zasluhy         1.0
# Josef Veselý          rad-m.-r.-stefanika  rad-t.-g.-masaryka         3.0
# Jiří Suchý             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
# Karel Kuttelwascher  medaile-za-hrdinstvi      rad-bileho-lva         1.0
# Jan Kačer              medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Karel Kryl             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
# Josef Štemberka        rad-t.-g.-masaryka  medaile-za-zasluhy         1.0
# Juraj Kukura           medaile-za-zasluhy  medaile-za-zasluhy         1.0
# Karel Kutlvašr        rad-m.-r.-stefanika      rad-bileho-lva         2.0
# Karel Pezl             medaile-za-zasluhy      rad-bileho-lva         1.0
# Josef Bílý            rad-m.-r.-stefanika      rad-bileho-lva         2.0
#
#                      druhy_rank  rozestup
# jmeno
# Josef Sedláček              3.0       4.0
# Viktor Fischl               3.0       5.0
# Radovan Procházka           4.0       5.0
# Josef Suk                   1.0       7.0
# Jiřina Bohdalová            1.0       8.0
# Emil Boček                  1.0       9.0
# Jaromír Jágr                1.0       9.0
# Francois Mitterrand         1.0       9.0
# Jiří Kolář                  2.0      11.0
# Karel Gott                  1.0      11.0
# Alois Šiška                 3.0      12.0
# Hana Hegerová               1.0      12.0
# Marie Svatošová             1.0      13.0
# Tomáš Sedláček              3.0      13.0
# František Fajtl             3.0      13.0
# Josef Buršík                1.0      14.0
# Rudolf Pernický             1.0      14.0
# Stanislav Hlučka            1.0      14.0
# Erazim Kohák                1.0      15.0
# Jan Šrámek                  1.0      16.0
# Josef Váňa                  2.0      17.0
# Josef Veselý                3.0      18.0
# Jiří Suchý                  1.0      18.0
# Karel Kuttelwascher         1.0      18.0
# Jan Kačer                   4.0      18.0
# Karel Kryl                  1.0      19.0
# Josef Štemberka             1.0      22.0
# Juraj Kukura                1.0      25.0
# Karel Kutlvašr              1.0      25.0
# Karel Pezl                  1.0      25.0
# Josef Bílý                  1.0      26.0

# %% [markdown]
# Samostatná ČR – zde již ručně očištěno od jmenovců:

# %%
vicenasobni[vicenasobni["poprve"] > 1992].sort_values(by="rozestup")
# Out:
#                      rok  poprve  podruhe prvni_prezident druhy_prezident  \
# jmeno
# Jiřina Bohdalová       2  2013.0   2021.0           Zeman           Zeman
# Emil Boček             2  2010.0   2019.0           Klaus           Zeman
# Jaromír Jágr           2  2010.0   2019.0           Klaus           Zeman
# Karel Gott             2  2009.0   2020.0           Klaus           Zeman
# Hana Hegerová          2  2002.0   2014.0           Havel           Zeman
# Marie Svatošová        2  2002.0   2015.0           Havel           Zeman
# Erazim Kohák           2  1998.0   2013.0           Havel           Zeman
# Jan Kačer              2  1998.0   2016.0           Havel           Zeman
# Jiří Suchý             2  1995.0   2013.0           Havel           Zeman
# Karel Kuttelwascher    2  1998.0   2016.0           Havel           Zeman
# Karel Kryl             2  1995.0   2014.0           Havel           Zeman
#
#                               prvni_metal         druhy_metal  prvni_rank  \
# jmeno
# Jiřina Bohdalová       medaile-za-zasluhy      rad-bileho-lva         1.0
# Emil Boček                 rad-bileho-lva      rad-bileho-lva         3.0
# Jaromír Jágr           medaile-za-zasluhy  medaile-za-zasluhy         2.0
# Karel Gott             medaile-za-zasluhy      rad-bileho-lva         1.0
# Hana Hegerová          medaile-za-zasluhy  rad-t.-g.-masaryka         3.0
# Marie Svatošová        medaile-za-zasluhy  medaile-za-zasluhy         3.0
# Erazim Kohák           medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Jan Kačer              medaile-za-zasluhy  rad-t.-g.-masaryka         1.0
# Jiří Suchý             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
# Karel Kuttelwascher  medaile-za-hrdinstvi      rad-bileho-lva         1.0
# Karel Kryl             medaile-za-zasluhy  rad-t.-g.-masaryka         2.0
#
#                      druhy_rank  rozestup
# jmeno
# Jiřina Bohdalová            1.0       8.0
# Emil Boček                  1.0       9.0
# Jaromír Jágr                1.0       9.0
# Karel Gott                  1.0      11.0
# Hana Hegerová               1.0      12.0
# Marie Svatošová             1.0      13.0
# Erazim Kohák                1.0      15.0
# Jan Kačer                   4.0      18.0
# Jiří Suchý                  1.0      18.0
# Karel Kuttelwascher         1.0      18.0
# Karel Kryl                  1.0      19.0

# %% [markdown]
# ## Nebožtíci

# %%
metaly[metaly["inmemoriam"] == True].groupby(["rok", "vyznamenani"])["id"].nunique().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
inmemoriamratio = metaly[metaly["inmemoriam"] == True].groupby("rok")["id"].nunique() / metaly.groupby("rok")["id"].nunique()

# %%
inmemoriamratiobezhrdinstvi = metaly[(metaly["inmemoriam"] == True) & (metaly["vyznamenani"] != "medaile-za-hrdinstvi")].groupby("rok")["id"].nunique() / metaly[metaly["vyznamenani"] != "medaile-za-hrdinstvi"].groupby("rok")["id"].nunique()

# %%
inmemoriamratio.plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
inmemoriamratiobezhrdinstvi.plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %% [markdown]
# ## Třídy a stupně

# %%
metaly.groupby(["rok","vyznamenani"])["id"].nunique().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly[metaly["rank"] == 1].groupby(["rok"])["id"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly.groupby(["rok","rank"])["id"].nunique().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
metaly.groupby("rank")["id"].nunique()
# Out:
# rank
# 1.0    600
# 2.0    331
# 3.0    349
# 4.0     76
# 5.0      5
# Name: id, dtype: int64

# %% [markdown]
# ## Notabilita Bílých lvů

# %%
lvi_extended = pd.read_csv("lions_e.csv")
lvi_extended = lvi_extended.reset_index()
lvi_extended["id"] = lvi_extended.index

# %% [markdown]
# O [notabilitě více zde](https://github.com/michalkasparek/who-Is-who/blob/main/0%20Basic%20Data%20Exploration.ipynb).

# %%
zebricek_podle_vyznamnosti = lvi_extended[lvi_extended["rok"] > 1992].sort_values(by="zebricek")[["rok","jmeno","prezident"]].reset_index().head(25)

# %%
zebricek_podle_vyznamnosti
# Out:
#     index     rok                        jmeno prezident
# 0      93  1999.0                Ronald Reagan     Havel
# 1      11  1998.0    William Jefferson Clinton     Havel
# 2     107  1999.0         Margaret Thatcherová     Havel
# 3      53  1999.0  Michail Sergejevič Gorbačov     Havel
# 4      39  1999.0                  George Bush     Havel
# 5       1  1996.0                  Alžběta II.     Havel
# 6      10  1997.0               Jacques Chirac     Havel
# 7      77  1999.0          François Mitterrand     Havel
# 8      65  1999.0                  Helmut Kohl     Havel
# 9      35  2000.0                 Willy Brandt     Havel
# 10    114  1999.0                  Lech Walesa     Havel
# 11      6  1995.0               Juan Carlos I.     Havel
# 12     57  2003.0                 Václav Havel     Klaus
# 13     83  1998.0             George S. Patton     Havel
# 14     98  2017.0  Gerhard Fritz Kurt Schröder     Zeman
# 15     82  2000.0           Olof Joachim Palme     Havel
# 16     31  1997.0     Madeleine K. Albrightová     Havel
# 17    116  1999.0             Simon Wiesenthal     Havel
# 18      0  2015.0  Abdullah II. bin Al Hussein     Zeman
# 19    115  2003.0       Richard von Weizsäcker     Klaus
# 20     44  2003.0             Alexander Dubček     Klaus
# 21     16  2014.0                Joachim Gauck     Zeman
# 22     23  2019.0                 Václav Klaus     Zeman
# 23     27  2000.0                 Johannes Rau     Havel
# 24     69  2000.0                Bruno Kreisky     Havel

# %%
zebricek_podle_vyznamnosti.to_csv("zebricek_podle_vyznamnosti.csv")

# %%
lvi_extended[lvi_extended["zebricek"] < 1001].groupby("rok")["id"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='rok'>

# %%
lvi_extended[(lvi_extended["zebricek"] < 1001) & (lvi_extended["rok"] == 1999)]
# Out:
#      index stat     vyznamenani                        jmeno  vyznamnost  \
# 39      39   cr  rad-bileho-lva                  George Bush   38.091080
# 53      53   cr  rad-bileho-lva  Michail Sergejevič Gorbačov   37.324436
# 65      65   cr  rad-bileho-lva                  Helmut Kohl   35.460560
# 77      77   cr  rad-bileho-lva          François Mitterrand   35.902332
# 93      93   cr  rad-bileho-lva                Ronald Reagan   39.705551
# 107    107   cr  rad-bileho-lva         Margaret Thatcherová   38.070229
# 114    114   cr  rad-bileho-lva                  Lech Walesa   35.411781
#
#      zebricek  narozeni   umrti     rok  rank  retez   skupina  inmemoriam  \
# 39      178.0    1924.0  2018.0  1999.0   1.0  False  občanská       False
# 53      147.0    1931.0  2022.0  1999.0   1.0  False  občanská       False
# 65      612.0    1930.0  2017.0  1999.0   1.0  False  občanská       False
# 77      470.0    1916.0  1996.0  1999.0   1.0  False  občanská        True
# 93       20.0    1911.0  2004.0  1999.0   1.0  False  občanská       False
# 107     144.0    1925.0  2013.0  1999.0   1.0  False  občanská       False
# 114     801.5    1943.0     NaN  1999.0   1.0  False  občanská       False
#
#     pohlavi prezident   id
# 39      muz     Havel   39
# 53      muz     Havel   53
# 65      muz     Havel   65
# 77      muz     Havel   77
# 93      muz     Havel   93
# 107    zena     Havel  107
# 114     muz     Havel  114

# %%
pd.DataFrame(lvi_extended.sort_values(by="zebricek").groupby("rok")["jmeno"].first())
# Out:
#                               jmeno
# rok
# 1990.0          François Mitterrand
# 1992.0               H. G. Skilling
# 1995.0               Juan Carlos I.
# 1996.0                  Alžběta II.
# 1997.0               Jacques Chirac
# 1998.0    William Jefferson Clinton
# 1999.0                Ronald Reagan
# 2000.0                 Willy Brandt
# 2002.0              Guido Venturoni
# 2003.0                 Václav Havel
# 2004.0       Aleksander Kwasniewsky
# 2005.0                 Josef Buršík
# 2006.0                  Josef Bryks
# 2007.0           Stanislav Hnělička
# 2008.0                Jiří Zenáhlík
# 2009.0                Heinz Fischer
# 2010.0    Lech Aleksander Kaczyński
# 2011.0                Václav Djačuk
# 2012.0               Alexander Beer
# 2013.0              Ivan Gašparovič
# 2014.0                Joachim Gauck
# 2015.0  Abdullah II. bin Al Hussein
# 2016.0                 Andrzej Duda
# 2017.0  Gerhard Fritz Kurt Schröder
# 2018.0               Antonín Švehla
# 2019.0                 Václav Klaus
# 2020.0                   Karel Gott
# 2021.0           Alfred Duff Cooper

# %%
lvi_extended["vek"] = lvi_extended["rok"] - lvi_extended["narozeni"]

# %%
lvi_extended[lvi_extended["inmemoriam"] == False].sort_values(by="vek").head(5)
# Out:
#     index stat     vyznamenani                        jmeno  vyznamnost  \
# 9       9   cr  rad-bileho-lva                 Andrzej Duda   32.687565
# 24     24   cr  rad-bileho-lva       Aleksander Kwasniewsky   31.260067
# 11     11   cr  rad-bileho-lva    William Jefferson Clinton   38.609379
# 0       0   cr  rad-bileho-lva  Abdullah II. bin Al Hussein   34.551716
# 26     26   cr  rad-bileho-lva                  Borut Pahor   30.235401
#
#     zebricek  narozeni  umrti     rok  rank  retez   skupina  inmemoriam  \
# 9    11227.0    1972.0    NaN  2016.0   1.0   True  občanská       False
# 24   12352.0    1954.0    NaN  2004.0   1.0   True  občanská       False
# 11      46.0    1946.0    NaN  1998.0   1.0   True  občanská       False
# 0     1917.0    1962.0    NaN  2015.0   1.0   True  občanská       False
# 26   30551.0    1963.0    NaN  2017.0   1.0   True  občanská       False
#
#    pohlavi prezident  id   vek
# 9      muz     Zeman   9  44.0
# 24     muz     Klaus  24  50.0
# 11     muz     Havel  11  52.0
# 0      muz     Zeman   0  53.0
# 26     muz     Zeman  26  54.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == False].sort_values(by="vek").tail(5)
# Out:
#     index stat     vyznamenani              jmeno  vyznamnost  zebricek  \
# 25     25   cr  rad-bileho-lva       Karel Lánský         NaN       NaN
# 50     50   cr  rad-bileho-lva     Imrich Gablech   19.191671  705058.0
# 33     33   cr  rad-bileho-lva     Alexander Beer         NaN       NaN
# 4       4   cr  rad-bileho-lva         Emil Boček         NaN       NaN
# 75     75   cr  rad-bileho-lva  Jindřich Macháček         NaN       NaN
#
#     narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 25    1924.0  2019.0  2018.0   1.0  False  občanská       False     muz
# 50    1915.0  2016.0  2009.0   3.0  False  vojenská       False     muz
# 33    1917.0  2015.0  2012.0   2.0  False  vojenská       False     muz
# 4     1923.0     NaN  2019.0   1.0  False  vojenská       False     muz
# 75       NaN     NaN  1997.0   4.0  False  vojenská       False     muz
#
#    prezident  id   vek
# 25     Zeman  25  94.0
# 50     Klaus  50  94.0
# 33     Klaus  33  95.0
# 4      Zeman   4  96.0
# 75     Havel  75   NaN

# %%
lvi_extended["posmrti"] = lvi_extended["rok"] - lvi_extended["umrti"]

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].sort_values(by="posmrti").head(10)
# Out:
#      index stat     vyznamenani                      jmeno  vyznamnost  \
# 21      21   cr  rad-bileho-lva  Lech Aleksander Kaczyński   33.079590
# 105    105   cr  rad-bileho-lva                Alois Šiška         NaN
# 40      40   cr  rad-bileho-lva               Otakar Černý         NaN
# 71      71   cr  rad-bileho-lva       Rudolf Severin Krzák   17.960215
# 22      22   cr  rad-bileho-lva               Petr Kellner   25.452185
# 62      62   cr  rad-bileho-lva               Josef Hyhlík         NaN
# 17      17   cr  rad-bileho-lva                 Karel Gott   31.278296
# 38      38   cr  rad-bileho-lva               Josef Buršík   22.357090
# 77      77   cr  rad-bileho-lva        François Mitterrand   35.902332
# 35      35   cr  rad-bileho-lva               Willy Brandt   35.375935
#
#      zebricek  narozeni   umrti     rok  rank  retez   skupina  inmemoriam  \
# 21     6440.5    1949.0  2010.0  2010.0   1.0   True  občanská        True
# 105       NaN    1914.0  2003.0  2003.0   3.0  False  vojenská        True
# 40        NaN    1919.0  2009.0  2009.0   1.0  False  vojenská        True
# 71   868324.5    1914.0  2004.0  2004.0   3.0  False  vojenská        True
# 22   431490.0    1964.0  2021.0  2021.0   1.0  False  občanská        True
# 62        NaN    1922.0  1997.0  1998.0   3.0  False  občanská        True
# 17     8761.0    1939.0  2019.0  2020.0   1.0  False  občanská        True
# 38   280977.5    1911.0  2002.0  2005.0   1.0  False  vojenská        True
# 77      470.0    1916.0  1996.0  1999.0   1.0  False  občanská        True
# 35      633.0    1913.0  1992.0  2000.0   1.0  False  občanská        True
#
#     pohlavi prezident   id   vek  posmrti
# 21      muz     Klaus   21  61.0      0.0
# 105     muz     Klaus  105  89.0      0.0
# 40      muz     Klaus   40  90.0      0.0
# 71      muz     Klaus   71  90.0      0.0
# 22      muz     Zeman   22  57.0      0.0
# 62      muz     Havel   62  76.0      1.0
# 17      muz     Zeman   17  81.0      1.0
# 38      muz     Klaus   38  94.0      3.0
# 77      muz     Havel   77  83.0      3.0
# 35      muz     Havel   35  87.0      8.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].sort_values(by="posmrti").tail(5)
# Out:
#     index stat     vyznamenani            jmeno  vyznamnost  zebricek  \
# 81     81   cr  rad-bileho-lva     Josef Ocelka         NaN       NaN
# 3       3   cr  rad-bileho-lva       Josef Bílý   20.048971  627090.0
# 29     29   cr  rad-bileho-lva   Antonín Švehla   26.397543   63483.0
# 7       7   cr  rad-bileho-lva  Stanislav Čeček   21.707483  427032.0
# 49     49   cr  rad-bileho-lva      Robert Fico   30.919975   15775.5
#
#     narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 81    1909.0  1942.0  2019.0   1.0  False  vojenská        True     muz
# 3     1872.0  1941.0  2018.0   1.0  False  vojenská        True     muz
# 29    1873.0  1933.0  2018.0   1.0  False  občanská        True     muz
# 7     1886.0  1930.0  2018.0   1.0  False  vojenská        True     muz
# 49    1964.0     NaN  2014.0   1.0  False  občanská        True     muz
#
#    prezident  id    vek  posmrti
# 81     Zeman  81  110.0     77.0
# 3      Zeman   3  146.0     77.0
# 29     Zeman  29  145.0     85.0
# 7      Zeman   7  132.0     88.0
# 49     Zeman  49   50.0      NaN

# %%
lvi_extended[lvi_extended["inmemoriam"] == True]["posmrti"].median()
# Out:
# 40.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].sort_values(by="umrti").head(5)
# Out:
#     index stat     vyznamenani            jmeno  vyznamnost  zebricek  \
# 7       7   cr  rad-bileho-lva  Stanislav Čeček   21.707483  427032.0
# 29     29   cr  rad-bileho-lva   Antonín Švehla   26.397543   63483.0
# 3       3   cr  rad-bileho-lva       Josef Bílý   20.048971  627090.0
# 81     81   cr  rad-bileho-lva     Josef Ocelka         NaN       NaN
# 47     47   cr  rad-bileho-lva      Alois Eliáš   27.110500   51954.0
#
#     narozeni   umrti     rok  rank  retez   skupina  inmemoriam pohlavi  \
# 7     1886.0  1930.0  2018.0   1.0  False  vojenská        True     muz
# 29    1873.0  1933.0  2018.0   1.0  False  občanská        True     muz
# 3     1872.0  1941.0  2018.0   1.0  False  vojenská        True     muz
# 81    1909.0  1942.0  2019.0   1.0  False  vojenská        True     muz
# 47    1890.0  1942.0  1996.0   1.0  False  vojenská        True     muz
#
#    prezident  id    vek  posmrti
# 7      Zeman   7  132.0     88.0
# 29     Zeman  29  145.0     85.0
# 3      Zeman   3  146.0     77.0
# 81     Zeman  81  110.0     77.0
# 47     Havel  47  106.0     54.0

# %%
lvi_extended[lvi_extended["inmemoriam"] == False].sort_values(by="posmrti").head(5)
# Out:
#      index  stat     vyznamenani                        jmeno  vyznamnost  \
# 1        1    cr  rad-bileho-lva                  Alžběta II.   39.511745
# 31      31    cr  rad-bileho-lva     Madeleine K. Albrightová   34.017853
# 91      91    cr  rad-bileho-lva            Radovan Procházka         NaN
# 53      53    cr  rad-bileho-lva  Michail Sergejevič Gorbačov   37.324436
# 124    124  csfr  rad-bileho-lva              Josef Škvorecký   28.360466
#
#      zebricek  narozeni   umrti     rok  rank  retez   skupina  inmemoriam  \
# 1       419.0    1926.0  2022.0  1996.0   1.0   True  občanská       False
# 31     1688.0    1937.0  2022.0  1997.0   1.0  False  občanská       False
# 91        NaN    1927.0  2020.0  1997.0   4.0  False  vojenská       False
# 53      147.0    1931.0  2022.0  1999.0   1.0  False  občanská       False
# 124   24888.0    1924.0  2012.0  1990.0   3.0  False       NaN       False
#
#     pohlavi prezident   id   vek  posmrti
# 1      zena     Havel    1  70.0    -26.0
# 31     zena     Havel   31  60.0    -25.0
# 91      muz     Havel   91  70.0    -23.0
# 53      muz     Havel   53  68.0    -23.0
# 124     muz     Havel  124  66.0    -22.0

# %%
lvi_extended[(lvi_extended["inmemoriam"] == False) & lvi_extended.posmrti.notnull()].sort_values(by="posmrti").tail(20)
# Out:
#      index  stat     vyznamenani                      jmeno  vyznamnost  \
# 50      50    cr  rad-bileho-lva             Imrich Gablech   19.191671
# 36      36    cr  rad-bileho-lva                   Jan Bret         NaN
# 116    116    cr  rad-bileho-lva           Simon Wiesenthal   33.570942
# 120    120  csfr  rad-bileho-lva        François Mitterrand   35.902332
# 27      27    cr  rad-bileho-lva               Johannes Rau   31.696262
# 87      87    cr  rad-bileho-lva               Anton Petrák         NaN
# 93      93    cr  rad-bileho-lva              Ronald Reagan   39.705551
# 109    109    cr  rad-bileho-lva                  Jan Velík         NaN
# 66      66    cr  rad-bileho-lva           Miluláš Končický         NaN
# 42      42    cr  rad-bileho-lva              Václav Djačuk         NaN
# 33      33    cr  rad-bileho-lva             Alexander Beer         NaN
# 121    121  csfr  rad-bileho-lva           Vladimír Krajina   22.397926
# 67      67    cr  rad-bileho-lva                Vasil Korol         NaN
# 92      92    cr  rad-bileho-lva         Pravomil L. Raichl         NaN
# 48      48    cr  rad-bileho-lva            František Fajtl   24.466726
# 90      90    cr  rad-bileho-lva         Karel J. Procházka         NaN
# 74      74    cr  rad-bileho-lva  Marie Ljalková-Lastovecká   23.347412
# 106    106    cr  rad-bileho-lva             Antonín Špaček         NaN
# 25      25    cr  rad-bileho-lva               Karel Lánský         NaN
# 84      84    cr  rad-bileho-lva            Rudolf Pernický   19.767851
#
#      zebricek  narozeni   umrti     rok  rank  retez   skupina  inmemoriam  \
# 50   705058.0    1915.0  2016.0  2009.0   3.0  False  vojenská       False
# 36        NaN    1923.0  2002.0  1995.0   3.0  False  vojenská       False
# 116    1793.0    1908.0  2005.0  1999.0   3.0  False  občanská       False
# 120     470.0    1916.0  1996.0  1990.0   1.0  False       NaN       False
# 27     5823.0    1931.0  2006.0  2000.0   1.0   True  občanská       False
# 87        NaN    1912.0  2009.0  2003.0   1.0  False  vojenská       False
# 93       20.0    1911.0  2004.0  1999.0   1.0  False  občanská       False
# 109       NaN    1921.0  2016.0  2011.0   2.0  False  vojenská       False
# 66        NaN    1925.0  2015.0  2011.0   2.0  False  vojenská       False
# 42        NaN    1920.0  2015.0  2011.0   5.0  False  vojenská       False
# 33        NaN    1917.0  2015.0  2012.0   2.0  False  vojenská       False
# 121  240550.0    1905.0  1993.0  1990.0   1.0  False       NaN       False
# 67        NaN    1922.0  2015.0  2012.0   4.0  False  vojenská       False
# 92        NaN    1921.0  2002.0  2000.0   5.0  False  vojenská       False
# 48   122172.0    1912.0  2006.0  2004.0   3.0  False  vojenská       False
# 90        NaN    1905.0  1999.0  1997.0   4.0  False  vojenská       False
# 74   478653.5    1920.0  2011.0  2010.0   2.0  False  vojenská       False
# 106       NaN    1917.0  2007.0  2006.0   1.0  False  vojenská       False
# 25        NaN    1924.0  2019.0  2018.0   1.0  False  občanská       False
# 84   584814.5    1915.0  2005.0  2005.0   1.0  False  vojenská       False
#
#     pohlavi prezident   id   vek  posmrti
# 50      muz     Klaus   50  94.0     -7.0
# 36      muz     Havel   36  72.0     -7.0
# 116     muz     Havel  116  91.0     -6.0
# 120     muz     Havel  120  74.0     -6.0
# 27      muz     Havel   27  69.0     -6.0
# 87      muz     Klaus   87  91.0     -6.0
# 93      muz     Havel   93  88.0     -5.0
# 109     muz     Klaus  109  90.0     -5.0
# 66      muz     Klaus   66  86.0     -4.0
# 42      muz     Klaus   42  91.0     -4.0
# 33      muz     Klaus   33  95.0     -3.0
# 121     muz     Havel  121  85.0     -3.0
# 67      muz     Klaus   67  90.0     -3.0
# 92      muz     Havel   92  79.0     -2.0
# 48      muz     Klaus   48  92.0     -2.0
# 90      muz     Havel   90  92.0     -2.0
# 74     zena     Klaus   74  90.0     -1.0
# 106     muz     Klaus  106  89.0     -1.0
# 25      muz     Zeman   25  94.0     -1.0
# 84      muz     Klaus   84  90.0      0.0

# %% [markdown]
# Jen pár týdnů se z ŘBL těšil Rudolf Pernický: V letech 1990 až 1992 byl předsedou Konfederace politických vězňů a poté byl jejím čestným předsedou. Poslední roky svého života trávil v Domově pro válečné veterány a i přes své chatrné zdraví (dlouhodobé problémy s cukrovkou) se v posledním roce pustil do boje proti zrušení tohoto útočiště pro válečné veterány. Svou bojovnost projevil i během předávání nejvyššího státního vyznamenání Řádu Bílého lva na podzim 2005, kam se osobně dostavil přesto, že se o dva týdny dříve musel podrobit složité operaci – amputaci nohou.[3]

# %%
lvi_extended.sort_values(by="zebricek").tail(60)
# Out:
#      index  stat     vyznamenani                      jmeno     vyznamnost  \
# 22      22    cr  rad-bileho-lva               Petr Kellner      25.452185
# 74      74    cr  rad-bileho-lva  Marie Ljalková-Lastovecká      23.347412
# 123    123  csfr  rad-bileho-lva             H. G. Skilling      20.104029
# 72      72    cr  rad-bileho-lva             Karel Kutlvašr      21.398306
# 56      56    cr  rad-bileho-lva                 Paul Hatry  507605.000000
# 70      70    cr  rad-bileho-lva              Ludvík Krejčí      20.644863
# 84      84    cr  rad-bileho-lva            Rudolf Pernický      19.767851
# 3        3    cr  rad-bileho-lva                 Josef Bílý      20.048971
# 60      60    cr  rad-bileho-lva             Bedřich Homola      19.372997
# 50      50    cr  rad-bileho-lva             Imrich Gablech      19.191671
# 88      88    cr  rad-bileho-lva                 Karel Pezl      18.834990
# 32      32    cr  rad-bileho-lva               Josef Bartík      18.353737
# 79      79    cr  rad-bileho-lva            Vladimír Nedvěd      18.147558
# 71      71    cr  rad-bileho-lva       Rudolf Severin Krzák      17.960215
# 110    110    cr  rad-bileho-lva            Guido Venturoni      19.899698
# 64      64    cr  rad-bileho-lva             Miroslav Kácha      17.734098
# 117    117    cr  rad-bileho-lva          Thomas Ray Wilson      18.984396
# 4        4    cr  rad-bileho-lva                 Emil Boček            NaN
# 12      12    cr  rad-bileho-lva              Bohuslav Ečer            NaN
# 18      18    cr  rad-bileho-lva             Alexander Hess            NaN
# 19      19    cr  rad-bileho-lva     v.v. František Chábera            NaN
# 20      20    cr  rad-bileho-lva              Karel Husárek            NaN
# 25      25    cr  rad-bileho-lva               Karel Lánský            NaN
# 33      33    cr  rad-bileho-lva             Alexander Beer            NaN
# 34      34    cr  rad-bileho-lva                 Emil Boček            NaN
# 36      36    cr  rad-bileho-lva                   Jan Bret            NaN
# 40      40    cr  rad-bileho-lva               Otakar Černý            NaN
# 41      41    cr  rad-bileho-lva       Antonín Mikuláš Číla            NaN
# 42      42    cr  rad-bileho-lva              Václav Djačuk            NaN
# 45      45    cr  rad-bileho-lva                 Josef Duda            NaN
# 52      52    cr  rad-bileho-lva          Vladimír Garncarz            NaN
# 55      55    cr  rad-bileho-lva              Antonín Hasal            NaN
# 59      59    cr  rad-bileho-lva         Stanislav Hnělička            NaN
# 61      61    cr  rad-bileho-lva              Rudolf Hrubec            NaN
# 62      62    cr  rad-bileho-lva               Josef Hyhlík            NaN
# 66      66    cr  rad-bileho-lva           Miluláš Končický            NaN
# 67      67    cr  rad-bileho-lva                Vasil Korol            NaN
# 68      68    cr  rad-bileho-lva            Jaroslav Krátký            NaN
# 75      75    cr  rad-bileho-lva          Jindřich Macháček            NaN
# 80      80    cr  rad-bileho-lva            Bedřich Neumann            NaN
# 81      81    cr  rad-bileho-lva               Josef Ocelka            NaN
# 86      86    cr  rad-bileho-lva                Felix Peřka            NaN
# 87      87    cr  rad-bileho-lva               Anton Petrák            NaN
# 89      89    cr  rad-bileho-lva               Jan Plovajko            NaN
# 90      90    cr  rad-bileho-lva         Karel J. Procházka            NaN
# 91      91    cr  rad-bileho-lva          Radovan Procházka            NaN
# 92      92    cr  rad-bileho-lva         Pravomil L. Raichl            NaN
# 94      94    cr  rad-bileho-lva              Josef Robotka            NaN
# 95      95    cr  rad-bileho-lva               Chanan Rozen            NaN
# 97      97    cr  rad-bileho-lva            Jaroslav Selner            NaN
# 100    100    cr  rad-bileho-lva             Oldřich Skácel            NaN
# 101    101    cr  rad-bileho-lva         František Slunečko            NaN
# 103    103    cr  rad-bileho-lva            Vilém Stanovský            NaN
# 104    104    cr  rad-bileho-lva                Oto Stehlík            NaN
# 105    105    cr  rad-bileho-lva                Alois Šiška            NaN
# 106    106    cr  rad-bileho-lva             Antonín Špaček            NaN
# 109    109    cr  rad-bileho-lva                  Jan Velík            NaN
# 111    111    cr  rad-bileho-lva        Sergej Vojcechovský            NaN
# 113    113    cr  rad-bileho-lva              Veleslav Wahl            NaN
# 118    118    cr  rad-bileho-lva              Jiří Zenáhlík            NaN
#
#       zebricek  narozeni   umrti     rok  rank  retez   skupina  inmemoriam  \
# 22    431490.0    1964.0  2021.0  2021.0   1.0  False  občanská        True
# 74    478653.5    1920.0  2011.0  2010.0   2.0  False  vojenská       False
# 123   495709.5    1912.0  2001.0  1992.0   3.0  False       NaN       False
# 72    499605.0    1895.0  1961.0  2017.0   1.0  False  vojenská        True
# 56    507605.0    1929.0  2010.0  1998.0   3.0  False  občanská       False
# 70    512313.0    1890.0  1972.0  2017.0   1.0  False  vojenská        True
# 84    584814.5    1915.0  2005.0  2005.0   1.0  False  vojenská       False
# 3     627090.0    1872.0  1941.0  2018.0   1.0  False  vojenská        True
# 60    638016.5    1887.0  1943.0  1998.0   2.0  False  vojenská        True
# 50    705058.0    1915.0  2016.0  2009.0   3.0  False  vojenská       False
# 88    770032.0    1927.0     NaN  2017.0   1.0  False  vojenská       False
# 32    830617.0    1897.0  1968.0  1998.0   3.0  False  vojenská        True
# 79    863368.0    1917.0  2012.0  1996.0   3.0  False  vojenská       False
# 71    868324.5    1914.0  2004.0  2004.0   3.0  False  vojenská        True
# 110   900010.0    1934.0     NaN  2002.0   3.0  False  občanská       False
# 64   1000308.0    1923.0  2010.0  1995.0   3.0  False  vojenská       False
# 117  1397787.0    1946.0     NaN  2002.0   3.0  False  občanská       False
# 4          NaN    1923.0     NaN  2019.0   1.0  False  vojenská       False
# 12         NaN    1893.0  1954.0  2019.0   1.0  False  vojenská        True
# 18         NaN    1898.0  1981.0  2021.0   1.0  False  vojenská        True
# 19         NaN    1912.0  1999.0  2020.0   1.0  False  vojenská        True
# 20         NaN    1893.0  1972.0  2018.0   1.0  False  vojenská        True
# 25         NaN    1924.0  2019.0  2018.0   1.0  False  občanská       False
# 33         NaN    1917.0  2015.0  2012.0   2.0  False  vojenská       False
# 34         NaN    1923.0     NaN  2010.0   3.0  False  vojenská       False
# 36         NaN    1923.0  2002.0  1995.0   3.0  False  vojenská       False
# 40         NaN    1919.0  2009.0  2009.0   1.0  False  vojenská        True
# 41         NaN    1883.0  1983.0  1998.0   2.0  False  vojenská        True
# 42         NaN    1920.0  2015.0  2011.0   5.0  False  vojenská       False
# 45         NaN    1905.0  1977.0  2002.0   3.0  False  vojenská        True
# 52         NaN    1924.0  2004.0  1995.0   3.0  False  vojenská       False
# 55         NaN    1893.0  1960.0  1995.0   2.0  False  vojenská        True
# 59         NaN    1922.0  2016.0  2007.0   2.0  False  vojenská       False
# 61         NaN    1914.0  1944.0  2007.0   1.0  False  vojenská        True
# 62         NaN    1922.0  1997.0  1998.0   3.0  False  občanská        True
# 66         NaN    1925.0  2015.0  2011.0   2.0  False  vojenská       False
# 67         NaN    1922.0  2015.0  2012.0   4.0  False  vojenská       False
# 68         NaN    1911.0  1945.0  1998.0   4.0  False  vojenská        True
# 75         NaN       NaN     NaN  1997.0   4.0  False  vojenská       False
# 80         NaN    1981.0  1964.0  1997.0   3.0  False  vojenská        True
# 81         NaN    1909.0  1942.0  2019.0   1.0  False  vojenská        True
# 86         NaN    1924.0  2005.0  1995.0   3.0  False  vojenská       False
# 87         NaN    1912.0  2009.0  2003.0   1.0  False  vojenská       False
# 89         NaN    1922.0  2020.0  2010.0   3.0  False  vojenská       False
# 90         NaN    1905.0  1999.0  1997.0   4.0  False  vojenská       False
# 91         NaN    1927.0  2020.0  1997.0   4.0  False  vojenská       False
# 92         NaN    1921.0  2002.0  2000.0   5.0  False  vojenská       False
# 94         NaN    1906.0  1952.0  1997.0   3.0  False  vojenská        True
# 95         NaN    1918.0  2013.0  1998.0   4.0  False  občanská       False
# 97         NaN    1906.0  1973.0  2019.0   1.0  False  vojenská        True
# 100        NaN    1908.0  2002.0  1995.0   3.0  False  vojenská       False
# 101        NaN    1886.0  1963.0  1998.0   3.0  False  vojenská        True
# 103        NaN    1896.0  1972.0  2000.0   3.0  False  vojenská        True
# 104        NaN    1924.0     NaN  2002.0   4.0  False  občanská       False
# 105        NaN    1914.0  2003.0  2003.0   3.0  False  vojenská        True
# 106        NaN    1917.0  2007.0  2006.0   1.0  False  vojenská       False
# 109        NaN    1921.0  2016.0  2011.0   2.0  False  vojenská       False
# 111        NaN    1883.0  1951.0  1997.0   3.0  False  vojenská        True
# 113        NaN    1922.0  1950.0  1995.0   2.0  False  občanská        True
# 118        NaN    1921.0     NaN  2008.0   1.0  False  vojenská       False
#
#     pohlavi prezident   id    vek  posmrti
# 22      muz     Zeman   22   57.0      0.0
# 74     zena     Klaus   74   90.0     -1.0
# 123     muz   Stráský  123   80.0     -9.0
# 72      muz     Zeman   72  122.0     56.0
# 56      muz     Havel   56   69.0    -12.0
# 70      muz     Zeman   70  127.0     45.0
# 84      muz     Klaus   84   90.0      0.0
# 3       muz     Zeman    3  146.0     77.0
# 60      muz     Havel   60  111.0     55.0
# 50      muz     Klaus   50   94.0     -7.0
# 88      muz     Zeman   88   90.0      NaN
# 32      muz     Havel   32  101.0     30.0
# 79      muz     Havel   79   79.0    -16.0
# 71      muz     Klaus   71   90.0      0.0
# 110     muz     Havel  110   68.0      NaN
# 64      muz     Havel   64   72.0    -15.0
# 117     muz     Havel  117   56.0      NaN
# 4       muz     Zeman    4   96.0      NaN
# 12      muz     Zeman   12  126.0     65.0
# 18      muz     Zeman   18  123.0     40.0
# 19      muz     Zeman   19  108.0     21.0
# 20      muz     Zeman   20  125.0     46.0
# 25      muz     Zeman   25   94.0     -1.0
# 33      muz     Klaus   33   95.0     -3.0
# 34      muz     Klaus   34   87.0      NaN
# 36      muz     Havel   36   72.0     -7.0
# 40      muz     Klaus   40   90.0      0.0
# 41      muz     Havel   41  115.0     15.0
# 42      muz     Klaus   42   91.0     -4.0
# 45      muz     Havel   45   97.0     25.0
# 52      muz     Havel   52   71.0     -9.0
# 55      muz     Havel   55  102.0     35.0
# 59      muz     Klaus   59   85.0     -9.0
# 61      muz     Klaus   61   93.0     63.0
# 62      muz     Havel   62   76.0      1.0
# 66      muz     Klaus   66   86.0     -4.0
# 67      muz     Klaus   67   90.0     -3.0
# 68      muz     Havel   68   87.0     53.0
# 75      muz     Havel   75    NaN      NaN
# 80      muz     Havel   80   16.0     33.0
# 81      muz     Zeman   81  110.0     77.0
# 86      muz     Havel   86   71.0    -10.0
# 87      muz     Klaus   87   91.0     -6.0
# 89      muz     Klaus   89   88.0    -10.0
# 90      muz     Havel   90   92.0     -2.0
# 91      muz     Havel   91   70.0    -23.0
# 92      muz     Havel   92   79.0     -2.0
# 94      muz     Havel   94   91.0     45.0
# 95      muz     Havel   95   80.0    -15.0
# 97      muz     Zeman   97  113.0     46.0
# 100     muz     Havel  100   87.0     -7.0
# 101     muz     Havel  101  112.0     35.0
# 103     muz     Havel  103  104.0     28.0
# 104     muz     Havel  104   78.0      NaN
# 105     muz     Klaus  105   89.0      0.0
# 106     muz     Klaus  106   89.0     -1.0
# 109     muz     Klaus  109   90.0     -5.0
# 111     muz     Havel  111  114.0     46.0
# 113     muz     Havel  113   73.0     45.0
# 118     muz     Klaus  118   87.0      NaN

# %%
lvi_extended[lvi_extended["inmemoriam"] == True].groupby("prezident")["posmrti"].median()
# Out:
# prezident
# Havel    33.0
# Klaus     1.5
# Zeman    55.0
# Name: posmrti, dtype: float64

# %% [markdown]
# Když už dával Klaus in memoriam, bylo to čerstvě zesnulým.

# %%
lvi_extended[["rok","prezident","jmeno","posmrti"]].to_csv("posmrti.csv", index=False)

# %% [markdown]
# ## Syntéza

# %%
synt_zeny = pd.Series(metaly[(metaly["stat"] == "cr") & (metaly["pohlavi"] == "zena")].groupby("prezident")["id"].nunique() / metaly[metaly["stat"] == "cr"].groupby("prezident")["id"].nunique(), name="zeny")

synt_prvnitridy = pd.Series(metaly[(metaly["stat"] == "cr") & (metaly["rank"] == 1)].groupby("prezident")["id"].nunique() / metaly[metaly["stat"] == "cr"].groupby("prezident")["id"].nunique(), name="prvni tridy a stupne")

synt_inmemoriam = pd.Series(metaly[(metaly["stat"] == "cr") & (metaly["inmemoriam"] == True)].groupby("prezident")["id"].nunique() / metaly[metaly["stat"] == "cr"].groupby("prezident")["id"].nunique(), name="in memoriam")

synt_vyznamni1000_zivi = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["zebricek"] < 1000) & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["id"].nunique() / lvi_extended[(lvi_extended["stat"] == "cr")  & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["id"].nunique(), name="tisicovka nejvyznamejsich lidi, bez in memoriam")

synt_vyznamni100000_zivi = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["zebricek"] < 100000) & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["id"].nunique() / lvi_extended[(lvi_extended["stat"] == "cr")  & (lvi_extended["inmemoriam"] == False)].groupby("prezident")["id"].nunique(), name="sto tisic nejvyznamejsich lidi, bez in memoriam")

# %%
synt2_inmemoriam_rekord = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["inmemoriam"] == True)].groupby("prezident")["posmrti"].max(), name="in memoriam ŘBL nejdele po smrti")
synt2_inmemoriam_median = pd.Series(lvi_extended[(lvi_extended["stat"] == "cr") & (lvi_extended["inmemoriam"] == True)].groupby("prezident")["posmrti"].median(), name="in memoriam ŘBL medián")

# %%
synteza = pd.DataFrame(index=["Havel","Klaus","Zeman"])
synteza = synteza.merge(synt_zeny.to_frame(), left_index=True, right_index=True)
synteza = synteza.merge(synt_prvnitridy.to_frame(), left_index=True, right_index=True)
synteza = synteza.merge(synt_inmemoriam.to_frame(), left_index=True, right_index=True)
synteza = synteza.merge(synt_vyznamni1000_zivi.to_frame(), left_index=True, right_index=True)

# %%
synteza2 = pd.DataFrame(index=["Havel","Klaus","Zeman"])
synteza2 = synteza2.merge(synt2_inmemoriam_median.to_frame(), left_index=True, right_index=True)
synteza2 = synteza2.merge(synt2_inmemoriam_rekord.to_frame(), left_index=True, right_index=True)

# %%
synteza
# Out:
#            zeny  prvni tridy a stupne  in memoriam  \
# Havel  0.120000              0.374000     0.232000
# Klaus  0.168539              0.262172     0.089888
# Zeman  0.159744              0.869010     0.230032
#
#        tisicovka nejvyznamejsich lidi, bez in memoriam
# Havel                                         0.243243
# Klaus                                              NaN
# Zeman                                              NaN

# %%
synteza2
# Out:
#        in memoriam ŘBL medián  in memoriam ŘBL nejdele po smrti
# Havel                    33.0                              55.0
# Klaus                     1.5                              63.0
# Zeman                    55.0                              88.0

# %%
synteza.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ⬆️GRAF2a

# %%
synteza2.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ⬆️GRAF2b: Rád bych ty prezidenty porovnal takhle na přímo, ideálně jedním grafem, jenže na ose Y se pohybujeme v jiných řádech/jednotkách: procenta vs. roky (a ty roky jsou v rozpětí 1,5 až 88).

# %% [markdown]
# ## Strojovna – není nutné studovat

# %%
jmena = metaly["jmeno"].sort_values().drop_duplicates().to_list()

# %%
with open("jmena" + ".txt", 'w+', encoding="utf-8") as seznam:
    seznam.write(str("\n".join(jmena)))

# %%
lions = metaly[metaly["vyznamenani"] == "rad-bileho-lva"]

# %%
lions.to_csv("lions.csv", index=False)

# %%
metaly.to_csv("export.csv", index=False)

# %%
metaly[(metaly["vyznamenani"] == "rad-t.-g.-masaryka") & (metaly["inmemoriam"] == True)].sort_values(by="rok",ascending=True)
# Out:
#       index  stat         vyznamenani                 jmeno     rok  rank  \
# 54       39  csfr  rad-t.-g.-masaryka      Alexander Hirner  1991.0   4.0
# 109     167  csfr  rad-t.-g.-masaryka         Josef Zvěřina  1991.0   2.0
# 110       6  csfr  rad-t.-g.-masaryka  Josef kardinál Beran  1991.0   1.0
# 111      13  csfr  rad-t.-g.-masaryka           Josef Čapek  1991.0   1.0
# 113      22  csfr  rad-t.-g.-masaryka           Jozef Felix  1991.0   3.0
# ...     ...   ...                 ...                   ...     ...   ...
# 1356     18    cr  rad-t.-g.-masaryka        Charles Craine  2017.0   1.0
# 1357    127    cr  rad-t.-g.-masaryka          Jože Plečnik  2017.0   1.0
# 1399     25    cr  rad-t.-g.-masaryka         Rajko Doleček  2018.0   1.0
# 1441     71    cr  rad-t.-g.-masaryka     pplk. Jan Jelínek  2019.0   1.0
# 1498    135    cr  rad-t.-g.-masaryka       Karel Raška II.  2021.0   1.0
#
#       retez skupina  inmemoriam pohlavi prezident    id
# 54    False     NaN        True     muz     Havel    54
# 109   False     NaN        True     muz     Havel   109
# 110   False     NaN        True     muz     Havel   110
# 111   False     NaN        True     muz     Havel   111
# 113   False     NaN        True     muz     Havel   113
# ...     ...     ...         ...     ...       ...   ...
# 1356  False     nan        True     muz     Zeman  1356
# 1357  False     nan        True     muz     Zeman  1357
# 1399  False     nan        True     muz     Zeman  1399
# 1441  False     nan        True     muz     Zeman  1441
# 1498  False     nan        True     muz     Zeman  1498
#
# [184 rows x 12 columns]

# %%
lvi_extended.groupby("umrti")["id"].nunique().nlargest(10)
# Out:
# umrti
# 2015.0    6
# 2002.0    4
# 2005.0    4
# 2016.0    4
# 1945.0    3
# 1972.0    3
# 2004.0    3
# 2006.0    3
# 2010.0    3
# 2011.0    3
# Name: id, dtype: int64

# %%
metaly[metaly.rok.eq(2003)].head(50)
# Out:
#      index stat           vyznamenani                          jmeno     rok  \
# 919     60   cr  medaile-za-hrdinstvi              Dominique Magnant  2003.0
# 920    127   cr  medaile-za-hrdinstvi                Georges Vergoni  2003.0
# 921     73   cr  medaile-za-hrdinstvi                 Jaroslav Novák  2003.0
# 922     61   cr  medaile-za-hrdinstvi               Roman Macharáček  2003.0
# 923     33   cr    medaile-za-zasluhy                     Adolf Born  2003.0
# 924    623   cr    medaile-za-zasluhy                 Dana Zátopková  2003.0
# 925    577   cr    medaile-za-zasluhy               Emília Vášáryová  2003.0
# 926     49   cr    medaile-za-zasluhy                   Erhard Busek  2003.0
# 927    486   cr    medaile-za-zasluhy               František Stárek  2003.0
# 928    580   cr    medaile-za-zasluhy            František Vencovský  2003.0
# 929    613   cr    medaile-za-zasluhy                 Herbert Werner  2003.0
# 930    447   cr    medaile-za-zasluhy                    Ivan Ruller  2003.0
# 931    519   cr    medaile-za-zasluhy                    Ivan Šetlík  2003.0
# 932    275   cr    medaile-za-zasluhy                    Jacek Kuroň  2003.0
# 933    424   cr    medaile-za-zasluhy                      Jan Princ  2003.0
# 934    230   cr    medaile-za-zasluhy                     Jiří Kodet  2003.0
# 935    138   cr    medaile-za-zasluhy    Johanna von Herzogenbergová  2003.0
# 936    292   cr    medaile-za-zasluhy                  Josef Liesler  2003.0
# 937    453   cr    medaile-za-zasluhy                Július Satinský  2003.0
# 938     44   cr    medaile-za-zasluhy                   Karel Brožík  2003.0
# 939    176   cr    medaile-za-zasluhy                Ladislav Chudík  2003.0
# 940    189   cr    medaile-za-zasluhy              Lena May Jegerová  2003.0
# 941    186   cr    medaile-za-zasluhy                 Lenka Janotová  2003.0
# 942    512   cr    medaile-za-zasluhy                 Lászlo Szigeti  2003.0
# 943    163   cr    medaile-za-zasluhy                    Martin Huba  2003.0
# 944    286   cr    medaile-za-zasluhy                   Milan Lasica  2003.0
# 945    221   cr    medaile-za-zasluhy                   Pavel Klener  2003.0
# 946     83   cr    medaile-za-zasluhy                  Peter Dvorský  2003.0
# 947    627   cr    medaile-za-zasluhy                     Petr Zeman  2003.0
# 948    285   cr    medaile-za-zasluhy             Plk. Bc. Jiří Lang  2003.0
# 949     52   cr    medaile-za-zasluhy            Ramiro Cibrian Uzal  2003.0
# 950      5   cr    medaile-za-zasluhy             Timothy Garton Ash  2003.0
# 951    123   cr    medaile-za-zasluhy               Vlasta Hammerová  2003.0
# 952    461   cr    medaile-za-zasluhy            Vratislav Schreiber  2003.0
# 953    474   cr    medaile-za-zasluhy                  Václav Snítil  2003.0
# 954     11   cr    medaile-za-zasluhy               Wolfgang Bandion  2003.0
# 955    554   cr    medaile-za-zasluhy                 Zdena Tominová  2003.0
# 956    209   cr    medaile-za-zasluhy  Zuzana Kalabisová - Růžičková  2003.0
# 957    298   cr    medaile-za-zasluhy                 Ľubomír Lipták  2003.0
# 958     46   cr        rad-bileho-lva               Alexander Dubček  2003.0
# 959    107   cr        rad-bileho-lva                    Alois Šiška  2003.0
# 960     89   cr        rad-bileho-lva                   Anton Petrák  2003.0
# 961    117   cr        rad-bileho-lva         Richard von Weizsäcker  2003.0
# 962     59   cr        rad-bileho-lva                   Václav Havel  2003.0
# 963     56   cr        rad-bileho-lva                    Árpád Göncz  2003.0
# 964    115   cr    rad-t.-g.-masaryka                   Adam Michnik  2003.0
# 965    178   cr    rad-t.-g.-masaryka               Antje Vollmerová  2003.0
# 966    157   cr    rad-t.-g.-masaryka                    Antonín Sum  2003.0
# 967      9   cr    rad-t.-g.-masaryka                Elena Bonnerová  2003.0
# 968    106   cr    rad-t.-g.-masaryka                    Emil Ludvík  2003.0
#
#      rank  retez   skupina  inmemoriam pohlavi prezident   id
# 919   NaN  False       NaN       False     muz     Klaus  919
# 920   NaN  False       NaN        True     muz     Klaus  920
# 921   NaN  False       NaN       False     muz     Klaus  921
# 922   NaN  False       NaN       False     muz     Klaus  922
# 923   1.0  False       NaN       False     muz     Klaus  923
# 924   2.0  False       NaN       False    zena     Klaus  924
# 925   1.0  False       NaN       False    zena     Klaus  925
# 926   2.0  False       NaN       False     muz     Klaus  926
# 927   2.0  False       NaN       False     muz     Klaus  927
# 928   2.0  False       NaN       False     muz     Klaus  928
# 929   2.0  False       NaN       False     muz     Klaus  929
# 930   2.0  False       NaN       False     muz     Klaus  930
# 931   2.0  False       NaN       False     muz     Klaus  931
# 932   2.0  False       NaN       False     muz     Klaus  932
# 933   2.0  False       NaN       False     muz     Klaus  933
# 934   1.0  False       NaN       False     muz     Klaus  934
# 935   2.0  False       NaN       False    zena     Klaus  935
# 936   2.0  False       NaN       False     muz     Klaus  936
# 937   1.0  False       NaN        True     muz     Klaus  937
# 938   2.0  False       NaN       False     muz     Klaus  938
# 939   1.0  False       NaN       False     muz     Klaus  939
# 940   1.0  False       NaN       False    zena     Klaus  940
# 941   2.0  False       NaN       False    zena     Klaus  941
# 942   1.0  False       NaN       False     muz     Klaus  942
# 943   1.0  False       NaN       False     muz     Klaus  943
# 944   1.0  False       NaN       False     muz     Klaus  944
# 945   2.0  False       NaN       False     muz     Klaus  945
# 946   1.0  False       NaN       False     muz     Klaus  946
# 947   2.0  False       NaN       False     muz     Klaus  947
# 948   2.0  False       NaN       False     muz     Klaus  948
# 949   3.0  False       NaN       False     muz     Klaus  949
# 950   1.0  False       NaN       False     muz     Klaus  950
# 951   2.0  False       NaN       False    zena     Klaus  951
# 952   2.0  False       NaN       False     muz     Klaus  952
# 953   2.0  False       NaN       False     muz     Klaus  953
# 954   1.0  False       NaN       False     muz     Klaus  954
# 955   1.0  False       NaN       False    zena     Klaus  955
# 956   2.0  False       NaN       False    zena     Klaus  956
# 957   1.0  False       NaN       False     muz     Klaus  957
# 958   1.0  False  občanská        True     muz     Klaus  958
# 959   3.0  False  vojenská        True     muz     Klaus  959
# 960   1.0  False  vojenská       False     muz     Klaus  960
# 961   1.0  False  občanská       False     muz     Klaus  961
# 962   1.0   True  občanská       False     muz     Klaus  962
# 963   1.0  False  občanská       False     muz     Klaus  963
# 964   3.0  False       nan       False     muz     Klaus  964
# 965   3.0  False       nan       False    zena     Klaus  965
# 966   3.0  False       nan       False     muz     Klaus  966
# 967   2.0  False       nan       False    zena     Klaus  967
# 968   3.0  False       nan       False     muz     Klaus  968

# %%
metaly[metaly.rok.isin([2004,2005,2006,2007,2008,2009,2010,2011,2012])].groupby("rok")["id"].nunique().mean()
# Out:
# 23.22222222222222

# %%
metaly[(metaly["prezident"] == "Zeman") & (metaly["vyznamenani"] != "medaile-za-hrdinstvi") & (metaly["rank"] != 1)]
# Out:
#       index stat         vyznamenani                      jmeno     rok  rank  \
# 1244    100   cr  rad-t.-g.-masaryka           Detlef Lingemann  2014.0   3.0
# 1248     94   cr  rad-t.-g.-masaryka           Michaela Küchler  2014.0   4.0
# 1307     48   cr      rad-bileho-lva   Dominik kardinál Duka OP  2016.0   3.0
# 1308    110   cr      rad-bileho-lva  Ferdinand Trauttmansdorff  2016.0   4.0
# 1310     96   cr  rad-t.-g.-masaryka           Adam Kwiatkowský  2016.0   3.0
# 1311     23   cr  rad-t.-g.-masaryka               Andrzej Dero  2016.0   3.0
# 1313     76   cr  rad-t.-g.-masaryka                  Jan Kačer  2016.0   4.0
# 1314     75   cr  rad-t.-g.-masaryka    Katarzyna Kacperczyková  2016.0   4.0
#
#       retez   skupina  inmemoriam pohlavi prezident    id
# 1244  False       nan       False     muz     Zeman  1244
# 1248  False       nan       False    zena     Zeman  1248
# 1307  False  občanská       False     muz     Zeman  1307
# 1308  False  občanská       False     muz     Zeman  1308
# 1310  False       nan       False     muz     Zeman  1310
# 1311  False       nan       False     muz     Zeman  1311
# 1313  False       nan       False     muz     Zeman  1313
# 1314  False       nan       False    zena     Zeman  1314

# %%
metaly[(metaly["vyznamenani"] == "medaile-za-zasluhy") & (metaly["rank"] == 4)]
# Out:
# Empty DataFrame
# Columns: [index, stat, vyznamenani, jmeno, rok, rank, retez, skupina, inmemoriam, pohlavi, prezident, id]
# Index: []

# %%
metaly[(metaly["vyznamenani"] == "rad-bileho-lva") & (metaly["prezident"] == "Klaus") & (metaly["inmemoriam"] == True)]
# Out:
#       index stat     vyznamenani                      jmeno     rok  rank  \
# 958      46   cr  rad-bileho-lva           Alexander Dubček  2003.0   1.0
# 959     107   cr  rad-bileho-lva                Alois Šiška  2003.0   3.0
# 994      73   cr  rad-bileho-lva       Rudolf Severin Krzák  2004.0   3.0
# 1017     40   cr  rad-bileho-lva               Josef Buršík  2005.0   1.0
# 1037     39   cr  rad-bileho-lva                Josef Bryks  2006.0   2.0
# 1063     63   cr  rad-bileho-lva              Rudolf Hrubec  2007.0   1.0
# 1114     42   cr  rad-bileho-lva               Otakar Černý  2009.0   1.0
# 1137     23   cr  rad-bileho-lva  Lech Aleksander Kaczyński  2010.0   1.0
#
#       retez   skupina  inmemoriam pohlavi prezident    id
# 958   False  občanská        True     muz     Klaus   958
# 959   False  vojenská        True     muz     Klaus   959
# 994   False  vojenská        True     muz     Klaus   994
# 1017  False  vojenská        True     muz     Klaus  1017
# 1037  False  vojenská        True     muz     Klaus  1037
# 1063  False  vojenská        True     muz     Klaus  1063
# 1114  False  vojenská        True     muz     Klaus  1114
# 1137   True  občanská        True     muz     Klaus  1137

# %%
metaly[metaly.jmeno.str.contains("Robotka")]
# Out:
#      index stat     vyznamenani          jmeno     rok  rank  retez   skupina  \
# 589     96   cr  rad-bileho-lva  Josef Robotka  1997.0   3.0  False  vojenská
#
#      inmemoriam pohlavi prezident   id
# 589        True     muz     Havel  589
